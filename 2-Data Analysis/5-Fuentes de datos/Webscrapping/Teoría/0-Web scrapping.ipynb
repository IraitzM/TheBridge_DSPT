# %% [markdown]
# # Webscrapping con Beautiful Soup y  Scrapy

# %% [markdown]
# El **web scraping** es el proceso de extracción de datos de sitios web de manera automatizada. Aprenderás los conceptos fundamentales y las herramientas necesarias para recolectar datos valiosos de la web, lo que te permitirá alimentar tus análisis y proyectos de Data Science con información fresca y relevante.

# %% [markdown]
# ## ¿Qué es?
#
# En términos sencillos, web scraping es como recolectar datos de una página web. Imagina que la web es una mina de información y que eres un minero recogiendo las gemas que necesitas para tu proyecto. En lugar de copiar y pegar manualmente, utilizamos código para automatizar el proceso.

# %% [markdown]
# ### ¿Por qué es importante el Web Scraping?

# %% [markdown]
# * **Acceso a datos no estructurados**: La mayoría de los datos en línea no están disponibles en formatos estructurados y listos para ser analizados. El web scraping te permite convertir datos no estructurados en un formato que puedas utilizar.
#
# * **Actualización de datos**: Muchas fuentes web se actualizan constantemente. El web scraping te permite mantener tus conjuntos de datos actualizados sin tener que hacerlo manualmente.
#
# * **Amplia gama de aplicaciones**: Desde la recopilación de datos de redes sociales hasta la obtención de precios de productos, el web scraping se utiliza en una amplia gama de aplicaciones de Data Science.

# %% [markdown]
# ## Proceso de Web Scraping

# %% [markdown]
# El web scraping generalmente sigue estos pasos:
#
# * **Hacer una solicitud HTTP**: obtenemos el contenido HTML de una página web.
#
# * **Análisis del HTML**: analizamos la estructura del HTML y encontrar los elementos que contienen los datos que necesitamos.
#
# * **Extracción de datos**: Una vez que hemos identificado los elementos, extraemos los datos relevantes.
#
# * **Almacenamiento de datos**: Podemos guardar los datos en un formato estructurado, como un archivo CSV o una base de datos.
#
# * **Limpieza y procesamiento**: A menudo, los datos extraídos necesitan ser limpiados y preprocesados antes de su análisis.

# %% [markdown]
# Es importante recordar que el web scraping puede tener implicaciones legales y éticas. Algunos sitios web prohíben la extracción de sus datos, y otros pueden limitar la velocidad a la que puedes hacer solicitudes para evitar la sobrecarga de sus servidores. Siempre debes respetar los términos de servicio de los sitios web y ser consciente de las leyes de privacidad y propiedad intelectual.

# %% [markdown]
# ## Intro HTML
#
# HTML (HyperText Markup Language) es el lenguaje de marcado utilizado para crear páginas web. Comprender los conceptos básicos de HTML es esencial para realizar web scraping, ya que te permite navegar y extraer datos de manera efectiva de sitios web.
#
# HTML utiliza etiquetas para estructurar el contenido de una página web. Aquí tienes una breve introducción a los conceptos básicos de HTML:
#
# 1. **Etiquetas:** Las etiquetas son elementos fundamentales en HTML. Comienzan con `<` y terminan con `>`. Por ejemplo, `<p>` se utiliza para definir un párrafo, `<h1>` para encabezados de nivel 1, y `<a>` para enlaces.
#
# 2. **Elementos:** Un elemento HTML se compone de una etiqueta de apertura, contenido y una etiqueta de cierre. Por ejemplo, `<p>Este es un párrafo.</p>`. El contenido es lo que se muestra en la página.
#
# 3. **Atributos:** Las etiquetas pueden contener atributos que proporcionan información adicional sobre el elemento. Por ejemplo, en `<a href="https://www.ejemplo.com">Enlace</a>`, "href" es un atributo que define la URL a la que el enlace apunta.
#
# 4. **Anidamiento:** Los elementos HTML pueden anidarse dentro de otros elementos. Por ejemplo, un párrafo `<p>` puede contener un enlace `<a>`. Es importante entender la jerarquía de anidamiento para navegar eficazmente por la estructura de una página web.
#
# 5. **Estructura:** Una página web típica tiene una estructura jerárquica con elementos como `<html>`, `<head>` (que contiene metadatos), `<body>` (que contiene el contenido visible), y muchos otros elementos como encabezados, listas, imágenes, etc.
#
# 6. **Clases e IDs:** Los elementos HTML pueden tener clases y IDs, que son atributos utilizados para aplicar estilos y facilitar la identificación de elementos específicos en una página. Estos son útiles al realizar web scraping para seleccionar elementos específicos.
#
# Para realizar web scraping, necesitas comprender cómo se organiza y etiqueta la información en una página web para poder identificar y extraer los datos que necesitas. El conocimiento de HTML es una base fundamental para esta tarea, ya que te permite navegar y seleccionar elementos específicos en el código fuente de una página web.

# %% [markdown]
# ### BeautifulSoup

# %% [markdown]
# Beautiful Soup es una popular biblioteca de Python utilizada para analizar y extraer información de documentos HTML y XML de una manera sencilla y eficaz. Esta biblioteca proporciona herramientas para navegar y buscar elementos dentro de la estructura de un documento web, lo que la convierte en una herramienta esencial para tareas de web scraping y procesamiento de datos web. Beautiful Soup facilita la extracción de datos de una página web al proporcionar una interfaz amigable que permite acceder a etiquetas, atributos y contenido de manera intuitiva, lo que la convierte en una elección común entre los científicos de datos y desarrolladores que trabajan con datos web.

# %%
# !pip install beautifulsoup4

# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
# from splinter import Browser
import numpy as np

pd.set_option('max_colwidth', 800)

# %% [markdown]
# Ahora, estamos listos para solicitar nuestra primera página web. No es nada complicado: guardamos la URL que queremos raspar en la variable URL, luego solicitamos la URL (requests.get (url)) y guardamos la respuesta en la variable de respuesta:

# %%
url = "https://www.filmaffinity.com/es/topgen.php"
response = requests.get(url)

# %%
print(response)
# Out:
# <Response [200]>

# %% [markdown]
# Pero necesitamos el contenido HTML de la página web solicitada, así que como siguiente paso guardamos el contenido de la respuesta a html:

# %%
html = response.content

# %%
print(html)
# Out:
# b'<!DOCTYPE html>\n<html lang="es">\n    <head>\n<title>Top Filmaffinity: las mejores pel\xc3\xadculas y series de la historia por pa\xc3\xadses - a\xc3\xb1os - g\xc3\xa9nero - FilmAffinity</title>\n<meta charset="UTF-8">\n<meta name="description" content="Explora la historia del cine: Descubre una selecci\xc3\xb3n \xc3\xbanica de Pel\xc3\xadculas y series populares, desde 1874 hasta 2024">\n<meta property="og:site_name" content="FilmAffinity">\n<meta name="twitter:site" value="@Filmaffinity" >\n<meta property="og:url" content="https://www.filmaffinity.com/es/topgen.php" />\n<meta property="og:title" content="FilmAffinity" />\n<meta property="og:description" content="Explora la historia del cine: Descubre una selecci\xc3\xb3n \xc3\xbanica de Pel\xc3\xadculas y series populares, desde 1874 hasta 2024" />\n<link rel="canonical" href="https://www.filmaffinity.com/es/topgen.php">\n<link rel="alternate" media="only screen and (max-width: 640px)" href="https://m.filmaffinity.com/es/topgen.php">\n<link rel="icon" type="image/png" href="/favicon.png">\n<link href="/style/bootstrap/fa-theme.5.3.2.1715006665.css" rel="stylesheet" type="text/css">\n<link href="/style/jquery/bootstrapselect/bootstrap-select.min.1621248810.css" rel="stylesheet" type="text/css">\n<link href="/style/jquery/slider/bootstrap-slider.min.1631702791.css" rel="stylesheet" type="text/css">\n<link href="/style/jquery/noty/noty.1554736533.css" rel="stylesheet" type="text/css">\n<link href="/style/jquery/scrolltabs/jquery.scrolling-tabs.min.1626695983.css" rel="stylesheet" type="text/css">\n<link href="/style/movies-list.1707134800.css" rel="stylesheet" type="text/css">\n<link href="/style/magic-check.min.1539096291.css" rel="stylesheet" type="text/css">\n<link href="/style/soulsmstop.1712071378.css" rel="stylesheet" type="text/css">\n<link href="/style/main3.1716385193.css" rel="stylesheet" type="text/css">\n<link href="/style/moviecards3.1712847422.css" rel="stylesheet" type="text/css">\n<link href="/style/jquery/slick/slick.1651839967.css" rel="stylesheet" type="text/css">\n<link href="/style/jquery/slick/slick-theme.1651839967.css" rel="stylesheet" type="text/css">\n<link href="/style/all.1700059266.css" rel="stylesheet" type="text/css">\n<link href="/style/fa-icons.1676894187.css" rel="stylesheet" type="text/css">\n<link href="/style/jquery/new-autocomplete/fa-autocomplete.1712661770.css" rel="stylesheet" type="text/css">\n<link href="/style/jquery/autocomplete/easy-autocomplete.min.1585727670.css" rel="stylesheet" type="text/css">\n<link href="/style/jquery/autocomplete/easy-autocomplete.themes.min.1585727670.css" rel="stylesheet" type="text/css">\n<script type="text/javascript" src="/js/local_es.1539096293.js"></script>\n<script type="text/javascript" src="/js/jquery/jquery-3.1.0.min.1539096302.js"></script>\n<script type="text/javascript" src="/js/jquery/jquery-migrate-1.4.1.min.1539096302.js"></script>\n<script type="text/javascript" src="/js/bootstrap/bootstrap.bundle.min.5.3.2.1694701167.js"></script>\n<script type="text/javascript" src="/js/jquery/plugin/bootstrapselect/bootstrap-select.1.14.0.1689931157.js"></script>\n<script type="text/javascript" src="/js/jquery/plugin/slider/bootstrap-slider.min.1631702815.js"></script>\n<script type="text/javascript" src="/js/jquery/plugin/noty/noty.min.1554736335.js"></script>\n<script type="text/javascript" src="/js/fa-noty.class.1554975957.js"></script>\n<script type="text/javascript" src="/js/jquery/plugin/scrolltabs/jquery.scrolling-tabs.min.1626695959.js"></script>\n<script type="text/javascript" src="/js/jquery/plugin/slick/slick.min.1651839936.js"></script>\n<script type="text/javascript" src="/js/crc32.1539096293.js"></script>\n<script type="text/javascript" src="/js/translate-context.1539096293.js"></script>\n<script type="text/javascript" src="/js/locale/texts-es_ES.1715179569.js"></script>\n<script type="text/javascript" src="/js/jquery/plugin/jquery.cookie.1539096308.js"></script>\n<script type="text/java ...

# %%
soup = bs(html, 'html.parser')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="es">
# <head>
# <title>Top Filmaffinity: las mejores películas y series de la historia por países - años - género - FilmAffinity</title>
# <meta charset="utf-8"/>
# <meta content="Explora la historia del cine: Descubre una selección única de Películas y series populares, desde 1874 hasta 2024" name="description"/>
# <meta content="FilmAffinity" property="og:site_name"/>
# <meta name="twitter:site" value="@Filmaffinity"/>
# <meta content="https://www.filmaffinity.com/es/topgen.php" property="og:url">
# <meta content="FilmAffinity" property="og:title">
# <meta content="Explora la historia del cine: Descubre una selección única de Películas y series populares, desde 1874 hasta 2024" property="og:description">
# <link href="https://www.filmaffinity.com/es/topgen.php" rel="canonical"/>
# <link href="https://m.filmaffinity.com/es/topgen.php" media="only screen and (max-width: 640px)" rel="alternate"/>
# <link href="/favicon.png" rel="icon" type="image/png"/>
# <link href="/style/bootstrap/fa-theme.5.3.2.1715006665.css" rel="stylesheet" type="text/css"/>
# <link href="/style/jquery/bootstrapselect/bootstrap-select.min.1621248810.css" rel="stylesheet" type="text/css"/>
# <link href="/style/jquery/slider/bootstrap-slider.min.1631702791.css" rel="stylesheet" type="text/css"/>
# <link href="/style/jquery/noty/noty.1554736533.css" rel="stylesheet" type="text/css"/>
# <link href="/style/jquery/scrolltabs/jquery.scrolling-tabs.min.1626695983.css" rel="stylesheet" type="text/css"/>
# <link href="/style/movies-list.1707134800.css" rel="stylesheet" type="text/css"/>
# <link href="/style/magic-check.min.1539096291.css" rel="stylesheet" type="text/css"/>
# <link href="/style/soulsmstop.1712071378.css" rel="stylesheet" type="text/css"/>
# <link href="/style/main3.1716385193.css" rel="stylesheet" type="text/css"/>
# <link href="/style/moviecards3.1712847422.css" rel="stylesheet" type="text/css"/>
# <link href="/style/jquery/slick/slick.1651839967.css" rel="stylesheet" type="text/css"/>
# <link href="/style/jquery/slick/slick-theme.1651839967.css" rel="stylesheet" type="text/css"/>
# <link href="/style/all.1700059266.css" rel="stylesheet" type="text/css"/>
# <link href="/style/fa-icons.1676894187.css" rel="stylesheet" type="text/css"/>
# <link href="/style/jquery/new-autocomplete/fa-autocomplete.1712661770.css" rel="stylesheet" type="text/css"/>
# <link href="/style/jquery/autocomplete/easy-autocomplete.min.1585727670.css" rel="stylesheet" type="text/css"/>
# <link href="/style/jquery/autocomplete/easy-autocomplete.themes.min.1585727670.css" rel="stylesheet" type="text/css"/>
# <script src="/js/local_es.1539096293.js" type="text/javascript"></script>
# <script src="/js/jquery/jquery-3.1.0.min.1539096302.js" type="text/javascript"></script>
# <script src="/js/jquery/jquery-migrate-1.4.1.min.1539096302.js" type="text/javascript"></script>
# <script src="/js/bootstrap/bootstrap.bundle.min.5.3.2.1694701167.js" type="text/javascript"></script>
# <script src="/js/jquery/plugin/bootstrapselect/bootstrap-select.1.14.0.1689931157.js" type="text/javascript"></script>
# <script src="/js/jquery/plugin/slider/bootstrap-slider.min.1631702815.js" type="text/javascript"></script>
# <script src="/js/jquery/plugin/noty/noty.min.1554736335.js" type="text/javascript"></script>
# <script src="/js/fa-noty.class.1554975957.js" type="text/javascript"></script>
# <script src="/js/jquery/plugin/scrolltabs/jquery.scrolling-tabs.min.1626695959.js" type="text/javascript"></script>
# <script src="/js/jquery/plugin/slick/slick.min.1651839936.js" type="text/javascript"></script>
# <script src="/js/crc32.1539096293.js" type="text/javascript"></script>
# <script src="/js/translate-context.1539096293.js" type="text/javascript"></script>
# <script src="/js/locale/texts-es_ES.1715179569.js" type="text/javascript"></script>
# <script src="/js/jquery/plugin/jquery.cookie.1539096308.js" type="text/javascript"></script>
# <script src="/js/ads.1539096293.js" type="text/javascript"></script>
# <script src="/js/main.1710341406.js" type="text/javascript"></script>
# <script src="/js/pagetop.1668696477.js" type="text/javascript"></script>
# <script src="/js/z-index-fix.1539096292.js" type="text/javascript"></script>
# <script src="/js/jquery/plugin/lazysizes/lazysizes.min.1602068375.js" type="text/javascript"></script>
# <script src="/js/fa-lists-tip.1539096292.js" type="text/javascript"></script>
# <script src="/js/jquery/plugin/new-autocomplete/fa-autocomplete.1675699495.js" type="text/javascript"></script>
# <script src="/js/jquery/plugin/autocomplete/jquery.easy-autocomplete.1671723118.js" type="text/javascript"></script>
# <script src="/js/bootstrap/bootstrap-autocomplete.1706000471.js" type="text/javascript"></script>
# <link href="https://www.filmaffinity.com/es/topgen.php" hreflang="es" rel="alternate"/>
# <link href="https://www.filmaffinity.com/en/topgen.php" hreflang="en" rel="alternate"/>
# <link href="https://www.filmaffinity.com/mx/topgen.php" hreflang="es-MX" rel="alternate"/>
# <link href="https://www.filmaffinity.com/ar/topgen.php" hreflang="es-AR" rel="alternate"/>
# <link href="https://www.filmaffinity.com/cl/topgen.php" hreflang="es-CL" rel="alternate"/>
# <link href="https://www.filmaffinity.com/co/topgen.php" hreflang="es-CO" rel="alternate"/>
# <link href="https://www.filmaffinity.com/uy/topgen.php" hreflang="es-UY" rel="alternate"/>
# <link href="https://www.filmaffinity.com/py/topgen.php" hreflang="es-PY" rel="alternate"/>
# <link href="https://www.filmaffinity.com/pe/topgen.php" hreflang="es-PE" rel="alternate"/>
# <link href="https://www.filmaffinity.com/ec/topgen.php" hreflang="es-EC" rel="alternate"/>
# <link href="https://www.filmaffinity.com/ve/topgen.php" hreflang="es-VE" rel="alternate"/>
# <link href="https://www.filmaffinity.com/cr/topgen.php" hreflang="es-CR" rel="alternate"/>
# <link href="https://www.filmaffinity.com/hn/topgen.php" hreflang="es-HN" rel="alternate"/>
# <link href="https://www.filmaffinity.com/gt/topgen.php" hreflang="es-GT" rel="alternate"/>
# <link href="https://www.filmaffinity.com/bo/topgen.php" hreflang="es-BO" rel="alternate"/>
# <link href="https://www.filmaffinity.com/do/topgen.php" hreflang="es-DO" rel="alternate"/>
# <link href="https://www.filmaffinity.com/us/topgen.php" hreflang="en-US" rel="alternate"/>
# <link href="https://www.filmaffinity.com/uk/topgen.php" hreflang="en-GB" rel="alternate"/>
# <link href="https://www.filmaffinity.com/ie/topgen.php" hreflang="en-IE" rel="alternate"/>
# <link href="https://www.filmaffinity.com/au/topgen.php" hreflang="en-AU" rel="alternate"/>
# <link href="https://www.filmaffinity.com/ca/topgen.php" hreflang="en-CA" rel="alternate"/>
# <!-- InMobi Choice. Consent Manager Tag v3.0 (for TCF 2.2) -->
# <script async="true" type="text/javascript">
# (function() {
#   var host = window.location.hostname;
#   var element = document.createElement('script');
#   var firstScript = document.getElementsByTagName('script')[0];
#   var url = 'https://cmp.inmobi.com'
#     .concat('/choice/', 'LBBrF-bdAtkuF', '/', host, '/choice.js?tag_version=V3');
#   var uspTries = 0;
#   var uspTriesLimit = 3;
#   element.async = true;
#   element.type = 'text/javascript';
#   element.src = url;
#
#   firstScript.parentNode.insertBefore(element, firstScript);
#
#   function makeStub() {
#     var TCF_LOCATOR_NAME = '__tcfapiLocator';
#     var queue = [];
#     var win = window;
#     var cmpFrame;
#
#     function addFrame() {
#       var doc = win.document;
#       var otherCMP = !!(win.frames[TCF_LOCATOR_NAME]);
#
#       if (!otherCMP) {
#         if (doc.body) {
#           var iframe = doc.createElement('iframe');
#
#           iframe.style.cssText = 'display:none';
#           iframe.name = TCF_LOCATOR_NAME;
#           doc.body.appendChild(iframe);
#         } else {
#           setTimeout(addFrame, 5);
#         }
#       }
#       return !otherCMP;
#     }
#
#     function tcfAPIHandler() {
#       var gdprApplies;
#       var args = arguments;
#
#       if (!args.length) {
#         return queue;
#       } else if (args[0] === 'setGdprApplies') {
#         if (
#           args.length > 3 &&
#           args[2] === 2 &&
#           typeof args[3] === 'boolean'
#         ) {
#           gdprApplies = args[3];
#           if (typeof args[2] === 'function') {
#             args[2]('set', true);
#           }
#         }
#       } else if (args[0] === 'ping') {
#         var retr = {
#           gdprApplies: gdprApplies,
#           cmpLoaded: false,
#           cmpStatus: 'stub'
#         };
#
#         if (typeof args[2] === 'function') {
#           args[2](retr);
#         }
#       } else {
#         if(args[0] === 'init' && typeof args[3] === 'object') {
#           args[3] = Object.assign(args[3], { tag_version: 'V3' });
#         }
#         queue.push(args);
#       }
#     }
#
#     function postMessageEventHandler(event) {
#       var msgIsString = typeof event.data === 'string';
#       var json = {};
#
#       try {
#         if (msgIsString) {
#           json = JSON.parse(event.data);
#         } else {
#           json = event.data;
#         }
#       } catch (ignore) {}
#
#       var payload = json.__tcfapiCall;
#
#       if (payload) {
#         window.__tcfapi(
#           payload.command,
#           payload.version,
#           function(retValue, success) {
#             var returnMsg = {
#               __tcfapiReturn: {
#                 returnValue: retValue,
#                 success: success,
#                 callId: payload.callId
#               }
#             };
#             if (msgIsString) {
#               returnMsg = JSON.stringify(returnMsg);
#             }
#             if (event && event.source && event.source.postMessage) {
#               event.source.postMessage(returnMsg, '*');
#             }
#           },
#           payload.parameter
#         );
#       }
#     }
#
#     while (win) {
#       try {
#         if (win.frames[TCF_LOCATOR_NAME]) {
#           cmpFrame = win;
#           break;
#         }
#       } catch (ignore) {}
#
#       if (win === window.top) {
#         break;
#       }
#       win = win.parent;
#     }
#     if (!cmpFrame) {
#       addFrame();
#       win.__tcfapi = tcfAPIHandler;
#       win.addEventListener('message', postMessageEventHandler, false);
#     }
#   };
#
#   makeStub();
#
#   var uspStubFunction = function() {
#     var arg = arguments;
#     if (typeof window.__uspapi !== uspStubFunction) {
#       setTimeout(function() {
#         if (typeof window.__uspapi !== 'undefined') {
#           window.__uspapi.apply(window.__uspapi, arg);
#         }
#       }, 500);
#     }
#   };
#
#   var checkIfUspIsReady = function() {
#     uspTries++;
#     if (window.__uspapi === uspStubFunction && uspTries < uspTriesLimit) {
#       console.warn('USP is not accessible');
#     } else {
#       clearInterval(uspInterval);
#     }
#   };
#
#   if (typeof window.__uspapi === 'undefined') {
#     window.__uspapi = uspStubFunction;
#     var uspInterval = setInterval(checkIfUspIsReady, 6000);
#   }
# })();
# </script>
# <!-- End InMobi Choice. Consent Manager Tag v3.0 (for TCF 2.2) --> <script>
#         $(function(){
#             sessPing("01665232944688268133642efa271cf5d062b72af4", 2400);
#             var tcTexts = TranslateContext.getInstance(commonTextsJs);
#         });
#     </script>
# <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script>
#
#         var googletag = googletag || {};
#
#         googletag.cmd = googletag.cmd || [];
#
#  </script>
# <script src="https://sc-devel.s3.eu-central-1.amazonaws.com/Skins/SMCService.js"></script>
# <script src="https://sc-devel.s3.eu-central-1.amazonaws.com/sc-tagmanager/filmaffinity.js"></script>
# <script async="async" src="https://cdn.smartclip-services.com/v1/Storage-a482323/smartclip-services/HeaderBidding/js/SmartclipConfig.js"></script>
# <script>
#   var sc = document.createElement ("script")
#   sc.src="https://cdn.smartclip-services.com/v1/Storage-a482323/smartclip-services/wrappers/sc__sync.js"
#   sc.onload = function(){
#   __sc__sync(["e40c3a8c-532f-469b-8e2a-1cc44f47c967"]) // id de la zona
#   }
#   document.head.appendChild(sc)
# </script> <script>
#         var _comscore = _comscore || [];
#         _comscore.push({ c1: "2", c2: "13181121" });
#         (function() {
#             var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#             s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#             el.parentNode.insertBefore(s, el);
#         })();
#     </script>
# <noscript>
# <img src="http://b.scorecardresearch.com/p?c1=2&amp;c2=13181121&amp;cv=2.0&amp;cj=1"/>
# </noscript>
# <script>$(function(){sendpv("95279ad7132a0da55c8934de3dcfc10c");});</script>
# </meta></meta></meta></head>
# <body>
# <!-- Google tag (gtag.js) -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-TZX5NYMKZC"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'G-TZX5NYMKZC');
# </script>
# <header id="page-header">
# <div id="header-top">
# <div class="cpanel top-wrapper">
# <div id="logo-container">
# <a href="https://www.filmaffinity.com/es/main.html">
# <img alt="logo" src="/images/logo4.png"/>
# <div class="logo-siteloc">España</div>
# </a>
# </div><!-- logo-container -->
# <div class="search-box">
# <div class="s-large" id="topsearch-ac">
# <form accept-charset="UTF-8" action="https://www.filmaffinity.com/es/search.php" method="get">
# <input class="s-large" id="top-search-input-2" name="stext" placeholder="Buscar" size="20" tabindex="1" type="text" value=""/>
# </form>
# <div class="s-load fa-3x"><i class="far fa-spinner-third fa-spin"></i></div>
# <i class="fal fa-times clear-search" style="display: none;"></i>
# <div class="advsearch"><a href="https://www.filmaffinity.com/es/advsearch.php">Búsqueda avanzada <i class="fas fa-angle-double-right"></i></a></div>
# </div><!-- topsearch -->
# </div><!--search-box -->
# <div id="user-login-container">
# <div id="login-register">
# <a class="sign-in" href="https://www.filmaffinity.com/es/login.php"><strong>Iniciar sesión</strong></a> / <a class="register" href="https://www.filmaffinity.com/es/register.php">Registrarse</a>
# </div>
# </div><!-- user-login -container -->
# </div>
# </div><!-- header-top -->
# <div id="header-bottom">
# <div class="cpanel news-wrapper">
# <ul id="awardsmenu">
# <li><a href="https://www.filmaffinity.com/es/topgen.php">Top FA</a></li><li class="sep">|</li>
# <li><a href="https://www.filmaffinity.com/es/rankings.php">Rankings FA</a></li><li class="sep">|</li>
# <li><a href="https://www.filmaffinity.com/es/category.php?id=2024films">Cine 2024</a></li><li class="sep">|</li>
# <li><a href="https://www.filmaffinity.com/es/best_2023.php">Resumen 2023</a></li><li class="sep">|</li>
# <li><a href="https://www.filmaffinity.com/es/calendar-tv.php">Calendario Series</a></li><li class="sep">|</li>
# <li><a href="https://www.filmaffinity.com/es/category.php?id=latest_reviews">Últ. críticas</a></li><li class="sep">|</li>
# <li><a href="https://www.filmaffinity.com/es/category.php?id=TRAILERS">Tráilers</a></li><li class="sep">|</li>
# <li><a href="https://www.filmaffinity.com/es/all_awards.php">Premios</a></li><li class="sep">|</li>
# <li><a href="https://www.filmaffinity.com/es/award-edition.php?edition-id=cannes_2024">Cannes 2024 <span class="tooltip-new">New</span></a></li><li class="sep">|</li>
# </ul>
# <div id="trmenu">
# <div class="social-logo" id="tw-top-logo"><a href="https://twitter.com/Filmaffinity" target="_BLANK" title="Sigue a FA en Twitter (60.000 followers)"><i class="fa-brands fa-x-twitter"></i></a></div>
# <div class="social-logo" id="in-top-logo"><a href="https://www.instagram.com/filmaffinity/" target="_BLANK" title="Sigue a FA en Instagram (155.000 followers)"><i class="fab fa-instagram"></i></a></div>
# </div>
# <div class="version-selector">
# <ul class="version">
# <li class="fixed" data-version="es" title="Cambiar de versión">España <i class="fas fa-chevron-down"></i></li>
# </ul>
# </div><!-- version-selector -->
# <div class="page-versions-pop fa-shadow">
# <div class="country-names">
# <ul class="continents">
# <li data-continent="america-north">
# <div class="header">Norteamérica <i class="fas fa-search-plus map-zoom"></i></div>
# <ul class="countries">
# <li data-country-id="us" data-version="us"><img alt="Estados Unidos" class="nflag" src="/imgs/countries2/US.png"/> US <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="ca" data-version="ca"><img alt="Canadá" class="nflag" src="/imgs/countries2/CA.png"/> Canadá <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="mx" data-version="mx"><img alt="México" class="nflag" src="/imgs/countries2/MX.png"/> México <i class="fas fa-arrow-right go-to-version"></i></li>
# </ul>
# </li>
# <li data-continent="europe">
# <div class="header">Europa <i class="fas fa-search-plus map-zoom"></i></div>
# <ul class="countries">
# <li data-country-id="es" data-version="es"><img alt="España" class="nflag" src="/imgs/countries2/ES.png"/> España <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="gb" data-version="uk"><img alt="Reino Unido" class="nflag" src="/imgs/countries2/GB.png"/> UK <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="ie" data-version="ie"><img alt="Irlanda" class="nflag" src="/imgs/countries2/IE.png"/> Irlanda <i class="fas fa-arrow-right go-to-version"></i></li>
# </ul>
# </li>
# <li data-continent="oceania">
# <div class="header">Oceanía <i class="fas fa-search-plus map-zoom"></i></div>
# <ul class="countries">
# <li data-country-id="au" data-version="au"><img alt="Australia" class="nflag" src="/imgs/countries2/AU.png"/> Australia <i class="fas fa-arrow-right go-to-version"></i></li>
# </ul>
# </li>
# </ul>
# <ul class="continents">
# <li data-continent="america-south">
# <div class="header">América del sur <i class="fas fa-search-plus map-zoom"></i> </div>
# <ul class="countries">
# <li data-country-id="ar" data-version="ar"><img alt="Argentina" class="nflag" src="/imgs/countries2/AR.png"/> Argentina <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="cl" data-version="cl"><img alt="Chile" class="nflag" src="/imgs/countries2/CL.png"/> Chile <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="co" data-version="co"><img alt="Colombia" class="nflag" src="/imgs/countries2/CO.png"/> Colombia <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="uy" data-version="uy"><img alt="Uruguay" class="nflag" src="/imgs/countries2/UY.png"/> Uruguay <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="py" data-version="py"><img alt="Paraguay" class="nflag" src="/imgs/countries2/PY.png"/> Paraguay <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="pe" data-version="pe"><img alt="Perú" class="nflag" src="/imgs/countries2/PE.png"/> Perú <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="ec" data-version="ec"><img alt="Ecuador" class="nflag" src="/imgs/countries2/EC.png"/> Ecuador <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="ve" data-version="ve"><img alt="Venezuela" class="nflag" src="/imgs/countries2/VE.png"/> Venezuela <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="cr" data-version="cr"><img alt="Costa Rica" class="nflag" src="/imgs/countries2/CR.png"/> Costa Rica <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="hn" data-version="hn"><img alt="Honduras" class="nflag" src="/imgs/countries2/HN.png"/> Honduras <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="gt" data-version="gt"><img alt="Guatemala" class="nflag" src="/imgs/countries2/GT.png"/> Guatemala <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="bo" data-version="bo"><img alt="Bolivia" class="nflag" src="/imgs/countries2/BO.png"/> Bolivia <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="do" data-version="do"><img alt="Rep. Dominicana" class="nflag" src="/imgs/countries2/DO.png"/> Rep. Dominicana <i class="fas fa-arrow-right go-to-version"></i></li>
# </ul>
# </li>
# </ul>
# <a class="more-info" href="https://www.filmaffinity.com/es/fa-international.php"><i class="fas fa-info-circle"></i> Más información</a>
# </div>
# </div>
# </div><!-- cpanel news-wrapper -->
# </div><!-- header-bottom second-nav -->
# </header><!-- header -->
# <script>favars = {"captchaType":"CLOUDFARE_INVISIBLE"};</script>
# <div class="cpanel adver-wrapper">
# <div class="adver-fix" id="top-ad">
# <div class="sc-top" id="sc-top">
# <script>
#
#                   googletag.cmd.push(function() {
#
#                         googletag.display('sc-top');
#
#                  });
#
#            </script>
# </div>
# <!-- sc-oop-->
# <div class="sc-oop" id="sc-oop">
# <script>
#
#                  googletag.cmd.push(function() {
#
#                         googletag.display('sc-oop');
#
#                  });
#
#            </script>
# </div>
# </div>
# </div>
# <div class="cpanel main-panel">
# <div id="main-content-table">
# <nav id="mt-left-cell">
# <div id="lsmenu">
# <div class="cat-container">
# <div class="lsmheader">Usuarios</div>
# <ul>
# <li><a class="rate-tours" href="https://www.filmaffinity.com/es/tours.php">Votar los tours</a></li><li><a class="sign-in" href="https://www.filmaffinity.com/es/login.php">Iniciar sesión</a></li><li><a href="https://www.filmaffinity.com/es/register.php">Registrarse</a></li></ul></div>
# <div class="cat-container">
# <div class="lsmheader">España</div>
# <ul>
# <li><a href="https://www.filmaffinity.com/es/cat_new_th_es.html">Películas en cartelera</a></li><li><a href="https://www.filmaffinity.com/es/cityTheaters.php">Cines España</a></li><li><a href="https://www.filmaffinity.com/es/rdcat.php?id=upc_th_es">Próximos estrenos</a></li><li><a href="https://www.filmaffinity.com/es/cat_new_sa_es.html">Estrenos Blu-ray venta</a></li><li><a href="https://www.filmaffinity.com/es/rdcat.php?id=upc_sa_es">Próximos Blu-ray venta</a></li><li><a href="https://www.filmaffinity.com/es/cat_new_re_es.html">Ya para alquilar</a></li><li><a href="https://www.filmaffinity.com/es/rdcat.php?id=upc_re_es">Próximamente alquiler</a></li><li><a href="https://www.filmaffinity.com/es/cat_new_netflix.html">Netflix</a></li><li><a href="https://www.filmaffinity.com/es/rdcat.php?id=upc_netflix">Netflix (próx)</a></li><li><a href="https://www.filmaffinity.com/es/cat_new_amazon_es.html">Amazon Prime</a></li><li><a href="https://www.filmaffinity.com/es/cat_new_movistar_f.html">Movistar Plus+ </a></li><li><a href="https://www.filmaffinity.com/es/cat_upc_movistar_f.html">Movistar Plus+ (próx)</a></li><li><a href="https://www.filmaffinity.com/es/cat_new_hbo_es.html">HBO Max</a></li><li><a href="https://www.filmaffinity.com/es/cat_disneyplus.html">Disney+</a></li><li><a href="https://www.filmaffinity.com/es/cat_new_filmin.html">Filmin</a></li><li><a href="https://www.filmaffinity.com/es/cat_apple_tv_plus.html">Apple TV+</a></li><li style="position: relative;"><strong><a href="https://www.filmaffinity.com/es/cat_skyshowtime.html">SkyShowtime</a></strong><div id="tooltip-new-menu" style="background: linear-gradient(to bottom, #FFA84C 52%, #FF7B0D 100%) repeat scroll 0 0 rgba(0, 0, 0, 0); border-radius: 5px; color: #FFFFFF; font-size: 11px; line-height: 0.8; padding: 2px 3px; position: absolute; right: 2px; text-shadow: 0.2em 0.2em 0.2em #BBBBBB; bottom: 2px; font-style: italic;"><strong>N</strong></div></li></ul></div>
# <div class="cat-container">
# <div class="lsmheader">USA - UK - FR</div>
# <ul>
# <li><a href="https://www.filmaffinity.com/es/cat_new_th_us.html">Estrenos USA</a></li><li><a href="https://www.filmaffinity.com/es/cat_new_th_uk.html">Estrenos Reino Unido</a></li><li><a href="https://www.filmaffinity.com/es/cat_new_th_fr.html">Estrenos Francia</a></li></ul></div>
# <div class="cat-container">
# <div class="lsmheader">Rankings FA</div>
# <ul>
# <li><a class="Rankings" href="https://www.filmaffinity.com/es/rankings.php">Todos los rankings</a></li><li><a href="https://www.filmaffinity.com/es/ranking.php?rn=ranking_fa_movies">El Top 1000 de FA</a></li></ul></div>
# <div class="cat-container">
# <div class="lsmheader">Secciones</div>
# <ul>
# <li><a href="https://www.filmaffinity.com/es/boxoffice.php">Taquilla</a></li><li><a href="https://www.filmaffinity.com/es/trailers.php">Trailers</a></li><li><a href="https://www.filmaffinity.com/es/latestevideos.php">Últimos trailers</a></li><li><a href="https://www.filmaffinity.com/es/latestreviews.php">Últimas críticas users</a></li><li><a href="https://www.filmaffinity.com/es/category.php?id=latest_reviews">Qué dice la crítica</a></li><li><a href="https://www.filmaffinity.com/es/topics.php">Películas por temas</a></li><li><a href="https://www.filmaffinity.com/es/movie-groups-all.php">Sagas &amp; Franquicias</a></li></ul></div>
# <div class="cat-container">
# <div class="lsmheader">Series de TV</div>
# <ul>
# <li><a href="https://www.filmaffinity.com/es/cat_current_tv.html">Series de actualidad</a></li><li><a href="https://www.filmaffinity.com/es/topgen.php?genres=-DO&amp;chv=1&amp;orderby=avg&amp;movietype=serie%7Conly-serie&amp;country=&amp;fromyear=1874&amp;toyear=2021&amp;ratingcount=3&amp;runtimemin=0&amp;runtimemax=4">Top series</a></li><li><a href="https://www.filmaffinity.com/es/tour.php?idtour=26">Vota Series de TV</a></li></ul></div>
# <div class="cat-container">
# <div class="lsmheader">TOPs</div>
# <ul>
# <li><a href="https://www.filmaffinity.com/es/topgen.php">Top Filmaffinity</a></li><li><a href="https://www.filmaffinity.com/es/best_tops.php">Lo mejor del TOP</a></li><li><a href="https://www.filmaffinity.com/es/topcat_new_th_es.html">Top Estrenos</a></li><li><a href="https://www.filmaffinity.com/es/topcat_new_sa_es.html">Top Estrenos Blu-ray</a></li><li><a href="https://www.filmaffinity.com/es/listsrank.php">Ranking de listas</a></li></ul></div>
# <div class="cat-container">
# <div class="lsmheader">Premios | Festivales</div>
# <ul>
# <li><a href="https://www.filmaffinity.com/es/all_awards.php">Premios y Festivales</a></li><li><a href="https://www.filmaffinity.com/es/oscar_data.php">Todos los Oscar</a></li><li><a href="https://www.filmaffinity.com/es/best_2023.php">Resumen 2023</a></li></ul></div>
# <div class="cat-container">
# <div class="lsmheader">Información</div>
# <ul>
# <li><a href="https://www.filmaffinity.com/es/site-guide.php">Acerca de FA</a></li><li><a href="https://www.filmaffinity.com/es/contact_us.php">Contacto</a></li></ul></div>
# </div>
# </nav>
# <div class="mt-content-wrapper">
# <main id="mt-content-cell">
# <div class="pt-in">
# <div id="sh-pos-abs">
# <div class="sh-header" title="compartir"><i class="fas fa-share-alt"></i></div>
# </div>
# <style>
#     #hidden-url {position: absolute; left: 65px; top: 2px; display: none; padding: 2px 6px 4px 6px; background: #fdcc1a; margin-top: 5px; width: 485px; border-radius: 5px; animation-duration: .3s; z-index: 100;}
#     #hidden-url input{ font-size: 14px; font-weight: bold; outline: none; border: 1px solid #DDDDDD; border-radius: 5px; padding: 8px 4px; width: 435px; margin-left: 5px; font-family: monospace;}
#     #hidden-url .hide-url {cursor: pointer; font-size: 22px; margin: 0 5px; color: #000; vertical-align: middle;}
#     #copy-clipboard {position: absolute; left: 0px; top: 31px; padding: 2px 6px; background: #fdcc1a; margin-top: 5px; animation-duration: .3s; border-bottom-right-radius: 4px; border-bottom-left-radius: 4px; width: 200px; cursor: pointer; padding-left: 15px;}
# </style>
# <script>
#
#     function hideOnClick( ){
#         $(document).click(function(event) {
#             if(!$(event.target).closest('.hd-sh-wrapper').length && !$(event.target).closest('#hidden-url').length) {
#                 if($('.hd-sh-wrapper').is(":visible")) {
#                     //$('.hidden-share-wrapper').hide();
#                     $('.sh-header').trigger('click');
#                 }
#             }
#         });
#     }
#
#     $(function() {
#         $('.hd-sh-wrapper').bind('animationEnd oAnimationEnd msAnimationEnd mozAnimationEnd webkitAnimationEnd', function(event){
#             if(  $(event.target).hasClass('nkoout') )
#             {
#                 $('.hd-sh-wrapper').hide();
#             }
#
#         });
#
#         $('#sh-pos-abs').toggle( function(){
#                 $('.sh-header').addClass('clicked');
#                 $('.hd-sh-wrapper').removeClass('nkoout').addClass('nkoin').show();
#             }, function(){
#                 $('.hd-sh-wrapper').removeClass('nkoin').addClass('nkoout');
#
#                 $('.main-sh').removeClass('clicked');
#                 if( $('#hidden-url').is(":visible") ) {
#                     $('#copy-to-clip').click();
#                 }
#         });
#
#         var pathname = encodeURI('https://www.filmaffinity.com/es/topgen.php');
#         var slideOptions = { direction: 'left' };
#
#         $('#copy-to-clip').toggle(
#             function(){
#                 $('#hidden-url').show();
#
#                     $('#hidden-url').find(':input').val(pathname);
#                     //$('#hidden-url').find(':input').select();
#                     var text = $('#hidden-url').find(':input').text();
#             },
#             function(){
#                     $('#hidden-url').hide();
#         });
#
#         $('#hidden-url').on('click', '#copy-clipboard', function(){
#             $(this).text( $('#copy-clipboard').attr('data-text') );
#             navigator.clipboard.writeText( pathname )
#                 .then(() => {
#                     console.log( pathname );
#             }).catch(err => {
#                     console.error('Could not copy text: ', err);
#             });
#         })
#
#         $('#hidden-url').find('.hide-url').click(function()
#         {
#             $('#copy-to-clip').trigger('click')
#         });
#
#         hideOnClick();
#     });
# </script>
# <div class="hd-sh-main-wrapper">
# <div class="hd-sh-wrapper">
# <a href="#" id="copy-to-clip" title="Copia la URL para compartir">
# <div class="share-icon" id="copy-to-clip-container"><i class="fas fa-link"></i></div>
# </a>
# <a class="fb-sh" href="https://www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Fwww.filmaffinity.com%2Fes%2Ftopgen.php&amp;t=Top Filmaffinity: las mejores películas y series de la historia por países - años - género" target="_BLANK" title="Comparte en Facebook">
# <div class="share-icon"><i class="fab fa-facebook-f"></i></div>
# </a>
# <a class="tw-sh" href="https://twitter.com/intent/tweet?text=Top%20Filmaffinity%3A%20las%20mejores%20pel%C3%ADculas%20y%20series%20de%20la%20historia%20por%20pa%C3%ADses%20-%20a%C3%B1os%20-%20g%C3%A9nero en @filmaffinity https%3A%2F%2Fwww.filmaffinity.com%2Fes%2Ftopgen.php" target="_BLANK" title="Comparte en Twitter">
# <div class="share-icon"><i class="fab fa-twitter"></i></div>
# </a>
# <a class="wh-sh" href="https://api.whatsapp.com/send?text=Top%20Filmaffinity%3A%20las%20mejores%20pel%C3%ADculas%20y%20series%20de%20la%20historia%20por%20pa%C3%ADses%20-%20a%C3%B1os%20-%20g%C3%A9nero en @filmaffinity https%3A%2F%2Fwww.filmaffinity.com%2Fes%2Ftopgen.php" target="_BLANK" title="Comparte en WhatsApp">
# <div class="share-icon"><i class="fab fa-whatsapp"></i></div>
# </a>
# </div>
# </div>
# <div id="hidden-url">
# <input size="55" type="text"/><i class="fas fa-times-circle hide-url"></i>
# <div data-text="Copiado" id="copy-clipboard">Haz click aquí para copiar la URL</div>
# </div>
# </div><!-- pt-in --><style>
# #mt-content-cell{overflow: initial;}
# .z-top-movies .fframe .form-wrapper #filter_top .flags-slider.year-wrapper{padding: 0 0px 30px 0px;}
# .z-top-movies .fframe .form-wrapper #filter_top .flags-slider.year-wrapper .dropdown.bootstrap-select{ border: 1px solid #333333}
# .z-top-movies .fframe .form-wrapper #filter_top .flags-slider.year-wrapper .dropdown.bootstrap-select:first-child{ margin-right: 25px;}
# </style>
# <h1 id="main-title">Top FilmAffinity</h1>
# <div class="z-top-movies">
# <script>
# $(document).ready(function(){
#
#     var defaultFilter = {
#         fromYear: 1874,
#         toYear: 2024,
#         genres: null,
#         minRatingCount: 1,
#         movieFilterForm: "full",
#         primaryCountries: null,
#         runtimeMin: 0,
#         runtimeMax: 7,
#     }
#
#     var flagsConfig = {"full":{"flags":"","sliderruntime":{"ticks":[0,20,30,45,60,90,120,1000],"labels":["0","20","30","45min","60","90","120","+120"],"positions":[0,12,25,40,55,70,85,100]},"subfilters":[]},"movie":{"flags":"*movie, -documentary, -show, -concert","sliderruntime":{"ticks":[0,60,90,120,1000],"labels":["0","60min","90","120","+120"],"positions":[0,30,50,70,100]},"subfilters":[{"type":"checkbox","options":{"ex-anim":"-animation, -interactive, -short","ex-tv":"-tv, -serie, -show, -episode, -miniserie"},"defaults":[]}]},"serie":{"flags":"+serie, +miniserie, +episode, +tv","sliderruntime":{"ticks":[0,20,40,60,1000],"labels":["0","20","40","60min","+60"],"positions":[0,20,40,70,100]},"subfilters":[{"type":"radio","options":{"only-serie":"*serie, -miniserie","only-miniserie":"*miniserie","only-episode":"*episode","only-telefilm":"*tv"},"defaults":[]}]},"documentary":{"flags":"*documentary,-concert,-show","sliderruntime":{"ticks":[0,5,10,20,40,60,90,120,1000],"labels":["0","5","10","20","40","60min","90","120","+120"],"positions":[0,10,20,30,45,60,75,85,100]},"subfilters":[{"type":"checkbox","options":{"ex-serie":"-tv, -serie, -show, -episode, -miniserie","ex-short":"-short, -medio"},"defaults":[]}]},"short":{"flags":"+short,+medio,-tv,-serie,-episode,-miniserie,-musicvideo","sliderruntime":{"ticks":[0,3,5,10,15,20,25,30,45,1000],"labels":["0",">3","5","10","15","20","25","30","45","+45"],"positions":[0,8,20,30,40,50,60,70,85,100]},"subfilters":[{"type":"radio","options":{"all":"","only-docu":"*documentary","only-animation":"*animation"},"defaults":["all"]}]},"animation":{"flags":"*animation","sliderruntime":{"ticks":[0,5,10,20,40,60,90,120,1000],"labels":["0","5","10","20","40min","60","90","120","+120"],"positions":[0,10,20,30,40,60,80,90,100]},"subfilters":[{"type":"radio","options":{"all":"","only-movie":"*movie","only-serie":"+serie,+miniserie","only-short":"*short"},"defaults":["all"]}]},"music":{"flags":"+musicvideo, +concert","sliderruntime":{"ticks":[0,5,10,60,1000],"labels":["0","5","10","60min","+120"],"positions":[0,20,40,70,100]},"subfilters":[{"type":"radio","options":{"all":"","only-musicvideo":"*musicvideo","only-concert":"*concert"},"defaults":["all"]}]}};
#     var filter = {"primaryCountries":null,"genres":null,"fromYear":1874,"toYear":2024,"runtimeMin":0,"runtimeMax":7,"minRatingCount":2,"movieFilterForm":"full","platforms":null,"orderby":"avg"};
#     var MIN_RATING_VALUES = [20,100,500,1000];
#     var RUNTIME_VALUES = [0,20,30,45,60,90,120,140];
#     var MIN_YEAR = 1874;
#     var MAX_YEAR = 2024;
#
#     var offersCache = {};
#     var offersTitle = '';
#
#     var tmPageSize = 30;
#     var tmResCount = 23431;
#     var tmFrom = 0;
#
#     var tcCommon = TranslateContext.getInstance(commonTextsJs);
#     var flagAdm = parseInt();
#     var configGrid = {"primaryCountries":null,"genres":null,"fromYear":1874,"toYear":2024,"runtimeMin":0,"runtimeMax":7,"minRatingCount":2,"movieFilterForm":"full","platforms":null,"orderby":"avg"};
#
#     $('#load-more-bt').click(function(){
#
#         $('#load-more-bt').hide();
#         $('#loading').show();
#
#         $.ajax({url: location.href,
#                 data: {from: tmFrom + tmPageSize, paramGrid: configGrid, orderby: configGrid.orderby, showHeader: parseInt($('.header-pg').length)},
#                 type: "POST",
#                 dataType: 'html',
#         }).done(function( html ) {
#
#             $('#loading').hide();
#
#             //$('#top-movies').append(html);
#             //$('.poster-list-grid').last().insertAfter(html);
#             if( $('.poster-list-grid').length >  0){
#                 var html = $('<ul class="poster-list-grid">'+ html +'</ul>');
#                 $(html).insertAfter('.poster-list-grid:last');
#             } else {
#                 $('#top-movies').append(html);
#             }
#
#             tmFrom += tmPageSize;
#
#             if(tmFrom + tmPageSize >= tmResCount)
#             {
#                 $('#load-more-div').remove();
#             }
#             else
#             {
#                 $('#load-more-bt').show();
#             }
#
#
#         });
#
#     });
#
#
#     $('body').on('click', function (e) {
#         if ($(e.target).data('toggle') !== 'popover'
#             && $(e.target).parents('.popover.in').length === 0) {
#             $('.popover').popover('dispose');
#         }
#     })
#
#
#     $('.z-top-movies #top-movies').on('click', '.providers', function()
#     {
#         var cell = $(this).closest('li');
#         var movieId = $('.movie-card', cell).attr('data-movie-id');
#
#         var button = $(this);
#
#         var params = {
#             action: 'getOffers',
#             movieId: movieId,
#         };
#
#         $.post(pageUrl('movies.ajax.php'), params, function(data)
#         {
#             var offers = $(data.offers);
#             offersTitle = $('.title', offers).text();
#
#             $('.title', offers).remove();
#
#             offersCache[movieId] = offers;
#
#             loadOffersPopover(button, movieId);
#         });
#
#
#     })
#
#
#     loadFilter(filter);
#     //renderLegend();
#     renderGenresLegend();
#
# /*
#     $('.platform-combo select').selectpicker({
#       multipleSeparator: ' '
#     }).on('changed.bs.select', function() {
#       $(this).selectpicker('refresh');
#     })
# */
#     $('#fromyear').selectpicker();
#     $('#toyear').selectpicker();
#
#
#     $('.fframe').on('submit', 'form', function(event)
#     {
#             var submitUrl = pageUrl('topgen.php');
#         if(flagAdm > 0)
#             submitUrl = pageUrl('adm/topgen.php');
#
#         event.preventDefault();
#
#         updateFlagsFilter();
#
#         var platformsSelect = $('.nav.nav-tabs li').map(function(idx, elem) {
#             if( $(elem).hasClass('selected') )
#                 return parseInt($(elem).attr('data-prov-id'));
#         }).get();
#
#         $('input[name="platforms"]').val(platformsSelect );
#
#         processedForm = filter2request( $('#filter_top').serializeArray() );
#
#         if( parseInt(processedForm.fromyear) > parseInt(processedForm.toyear) ){
#             var faNoty = FaNoty.getInstance();
#             faNoty.show('error', tcCommon.t('Error top years'), {layout: 'center'});
#         } else {
#             $.ajax({
#                 method: "GET",
#                 url: submitUrl,
#                 data: processedForm,
#             })
#             .done(function( msg ) {
#                location.assign( submitUrl );
#             });
#         }
#     })
#     .on('click', '.reset-filter', function()
#     {
#         loadFilter(defaultFilter);
#
#         $('#fromyear').selectpicker('val', defaultFilter.fromYear.toString());
#         $('#toyear').selectpicker('val', defaultFilter.toYear.toString());
#         $('input[name="orderby"]').val('avg');
#
#     })
#
#
#     .on('change', '[name="flags-type"]', function()
#     {
#         changeFlagsType($(this).val());
#         changeSlider( $(this).val() );
#     })
#
#
#     .on('change', '.platforms', function()
#     {
#         updatePlatformsValue();
#     })
#
#     $('.genre-combo').on('hide.bs.dropdown', '.dropdown', function (e)
#     {
#         if(e.clickEvent != undefined && $(e.clickEvent.target).closest('.dropdown-item').length > 0)
#         {
#             e.preventDefault();
#         }
#     })
#
#     .on('click', '.close-combo', function()
#     {
#         $(this).closest('.dropdown').find('.dropdown-toggle').dropdown('toggle');
#     })
#
#     .on('click', '.reset-combo', function()
#     {
#         let menu = $(this).closest('.dropdown-menu');
#
#         $.each($('input:checked', menu), function(index, checkedInput)
#         {
#             setGenreCheck($(checkedInput).closest('label'), false);
#
#         });
#
#         menu.find('.include').removeClass('include');
#         menu.find('.exclude').removeClass('exclude');
#
#         renderGenresLegend();
#     })
#
#
#     .on('click', 'label', function(e)
#     {
#         e.preventDefault();
#
#         let label = $(this);
#         let input = $('input', label);
#         let group = label.closest('.btn-group');
#
#
#         //Aqui se hace click en el texto
#         if(!input.prop('disabled'))
#         {
#             let toCheck = !input.is(':checked');
#
#             $.each($('input:checked', group), function(index, checkedInput)
#             {
#                 setGenreCheck($(checkedInput).closest('label'), false);
#             });
#
#             if(toCheck)
#             {
#                 setGenreCheck(label, true);
#                 toggleClass( group, label );
#             }else{
#                 toggleClass( group, label );
#             }
#         }
#         else
#         {
#             //toggleClass( group, label );
#             //Aqui se hace click en alguna de las aspas
#             if($('input:checked', group).length == 0)
#             {
#                 //si no hay nada marcado, incluimos
#                 $('label:eq(0)', group).trigger('click');
#             }
#             else if($('input:checked', group).index() == 0)
#             {
#                 //si está marcado el incluir, marcamos el excluir
#                 $('label:eq(2)', group).trigger('click');
#             }
#             else
#             {
#                 $.each($('input:checked', group), function(index, checkedInput)
#                 {
#                     setGenreCheck($(checkedInput).closest('label'), false);
#                 });
#             }
#         }
#
#         //renderLegend();
#         renderGenresLegend();
#
#     })
#
#     //Si pulsan en algunos de los check, hay que poner disabled el valor del genre-combo
#     $('.flags-content').on('click', 'div[data-flag="movie"] .fa-btn-checkbox, div[data-flag="serie"] .fa-btn-checkbox, div[data-flag="documentary"] .fa-btn-checkbox', function(e){
#         if(!$(this).hasClass('disabled')){
#             if( $(this).find('input').attr('data-option') == 'ex-anim' && $(this).hasClass('active')){
#                 $('.genre-combo .dropdown-item[data-value="AN"]').removeClass('disabled');
#             } else if($(this).find('input').attr('data-option') == 'ex-anim') {
#                 $('.genre-combo .dropdown-item[data-value="AN"]').addClass('disabled');
#             }
#
#             if( $(this).find('input').attr('data-option') == 'ex-docu' && $(this).hasClass('active')){
#                 $('.genre-combo .dropdown-item[data-value="DO"]').removeClass('disabled');
#             } else if($(this).find('input').attr('data-option') == 'ex-docu') {
#                 $('.genre-combo .dropdown-item[data-value="DO"]').addClass('disabled');
#             }
#
#             if( $(this).find('input').attr('data-option') == 'ex-serie' && $(this).hasClass('active')){
#                 $('.genre-combo .dropdown-item[data-value="TV_SE"]').removeClass('disabled');
#             } else if($(this).find('input').attr('data-option') == 'ex-serie'){
#                 $('.genre-combo .dropdown-item[data-value="TV_SE"]').addClass('disabled');
#             }
#
#         }
#     })
#
#     //Si pulsan en algunos de genre-combo, disabled el check
#     $('.genre-combo').on('click', '.box .dropdown-item', function(){
#         if( !$(this).hasClass('disabled') && $(this).attr('data-value') == 'AN' ){
#             $('.flags-content .fa-btn-checkbox input[data-option="ex-anim"]').closest('.fa-btn-checkbox').addClass('disabled');
#         }
#
#         if( !$(this).hasClass('disabled') && $(this).attr('data-value') == 'DO' ){
#             $('.flags-content .fa-btn-checkbox input[data-option="ex-docu"]').closest('.fa-btn-checkbox').addClass('disabled');
#         }
#
#         if( !$(this).hasClass('disabled') && $(this).attr('data-value') == 'TV_SE' ){
#             $('.flags-content .fa-btn-checkbox input[data-option="ex-serie"]').closest('.fa-btn-checkbox').addClass('disabled');
#         }
#
#         if( $(this).closest('.btn-group').find('.active').length == 0 && $(this).attr('data-value') == 'AN'){
#             $('.flags-content .fa-btn-checkbox input[data-option="ex-anim"]').closest('.fa-btn-checkbox').removeClass('disabled');
#         }
#
#         if( $(this).closest('.btn-group').find('.active').length == 0 && $(this).attr('data-value') == 'DO'){
#             $('.flags-content .fa-btn-checkbox input[data-option="ex-docu"]').closest('.fa-btn-checkbox').removeClass('disabled');
#         }
#
#         if( $(this).closest('.btn-group').find('.active').length == 0 && $(this).attr('data-value') == 'TV_SE'){
#             $('.flags-content .fa-btn-checkbox input[data-option="ex-serie"]').closest('.fa-btn-checkbox').removeClass('disabled');
#         }
#
#     });
#
# /*
#     para poder mover los años con las flechas del teclado
#     $('.flags-slider').on('click', '#slideryear .min-slider-handle', function(){
#         $('#slideryear').find('.min-slider-handle').focus();
#     })
#
#     $('.flags-slider').on('click', '#slideryear .max-slider-handle', function(){
#         $('#slideryear').find('.max-slider-handle').focus();
#     })
# */
#     $('.country-combo').on('click', '.bootstrap-select', function(){
#         var ulList = $(this).find('.dropdown-menu ul li');
#
#         ulList.each(function(index, value){
#             var wrapper = $(value).find('.flag-wrapper'),
#             countryId = $(wrapper).attr('id');
#             if( typeof countryId != 'undefined'){
#                 countryId = countryId.substr(0,2);
#                 var src = $('select#country option[value="'+ countryId + '"]').attr('data-style');
#                 $(value).find('.flag-wrapper').html( src );
#             }
#
#         })
#
#     })
#
#     $('a[href*=#].up-button').click(function() {
#         $('html,body').animate({scrollTop:'0px'}, 150);
#         return false;
#     });
#
#
#     function setGenreCheck(label, value)
#     {
#         if(value)
#         {
#             label.addClass('active');
#         }
#         else
#         {
#             label.removeClass('active');
#         }
#
#         $('input', label).prop('checked', value);
#     }
#
#     function setGenreState(labelText, genre)
#     {
#         var state = genre.substr(0,1);
#         if( state == '+' )
#         {
#             labelText.addClass('include');
#         }
#         else if( state == '-' )
#         {
#             labelText.addClass('exclude');
#         }
#     }
#
#     function toggleClass( group, clicklabel )
#     {
#         let label = group.find('.text');
#
#         if( label.hasClass('include') ){
#             if( clicklabel.find('.fa-check').length == 0 )
#                 label.removeClass('include').addClass('exclude');
#             else
#                 label.removeClass('include');
#
#         }else if( label.hasClass('exclude') ){
#
#             label.removeClass('exclude');
#
#             if( clicklabel.find('.fa-check').length > 0 ){
#                 label.addClass('include');
#             }
#
#         }else{
#
#             if( clicklabel.find('.fa-times').length > 0 )
#                 label.addClass('exclude');
#             else if( clicklabel.find('.fa-check').length > 0 )
#                 label.addClass('include');
#
#         }
#     }
#
#     function setFlag(label, status)
#     {
#         if(status)
#         {
#             label.addClass('active');
#         }
#         else
#         {
#             label.removeClass('active');
#         }
#
#         $('input', label).prop('checked', status);
#
#     }
#
#
#     function updateFlagsFilter()
#     {
#         var flagType = $('[name="flags-type"]').val();
#
#         var options = new Array();
#
#
#         var flagOptions = $('.flags-content [data-flag="' + flagType + '"] input');
#         $.each(flagOptions, function(index, input)
#         {
#             if($(input).prop('checked'))
#             {
#                 options.push($(input).attr('data-option'));
#             }
#         });
#
#         var flagFilter = flagType + '|' + options.join(':');
#
#
#         $('.fframe [name="movietype"]').val(flagFilter);
#
#     }
#
#     function loadFilterSliders(gen_filter)
#     {
#         if(gen_filter.runtime[0] == undefined)
#             gen_filter.runtime[0] = defaultFilter.runtimeMin;
#
#         if(gen_filter.runtime[1] == undefined)
#             gen_filter.runtime[1] = defaultFilter.runtimeMax;
#
#         $('#filter_top .flags-slider').find('.sliderratings').slider({
#             ticks: [20, 100, 500, 1000],
#             ticks_labels: ['+20', '+100', '+500', '+1000'],
#             ticks_positions: [0, 33, 66, 100],
#             min: 20,
#             lock_to_ticks: true,
#         }).slider('setValue', gen_filter.minRatingCount);
#
#         if( $('#filter_top .flags-slider').find('.sliderruntime').slider().length > 0 )
# ...
# </div>
# <div class="mc-info-container">
# <div class="mc-title"><a href="https://www.filmaffinity.com/es/film684718.html" title="Ser o no ser">Ser o no ser</a></div>
# <div class="d-flex">
# <img alt="Estados Unidos" class="nflag" src="/imgs/countries2/US.png"/><span class="mc-year">1942</span>
# </div>
# <div class="mc-director"><div class="credits"><span class="nb"><a href="https://www.filmaffinity.com/es/name.php?name-id=804987680" title="Ernst Lubitsch">Ernst Lubitsch</a></span></div></div>
# <div class="mc-cast"><div class="credits"><span class="nb"><a href="https://www.filmaffinity.com/es/name.php?name-id=879606078" title="Carole Lombard">Carole Lombard</a>,</span> <span class="nb"><a href="https://www.filmaffinity.com/es/name.php?name-id=597542430" title="Jack Benny">Jack Benny</a>,</span> <span class="nb"><a href="https://www.filmaffinity.com/es/name.php?name-id=707109860" title="Robert Stack">Robert Stack</a>,</span> <span class="nb"><a href="https://www.filmaffinity.com/es/name.php?name-id=262149081" title="Stanley Ridges">Stanley Ridges</a>,</span> <span class="nb"><a href="https://www.filmaffinity.com/es/name.php?name-id=775260052" title="Felix Bressart">Felix Bressart</a></span> ...</div></div>
# </div>
# <div class="mc-actions">
# </div>
# <div class="lists-box"></div>
# </div>
# </li>
# <li class="data">
# <div class="avg-rating">8,5</div>
# <div class="rat-count">36.082 <i class="fa fa-simple-user-o-fa"></i></div>
# </li>
# </ul>
# </li>
# <li>
# <ul>
# <li class="position">27</li>
# <li class="content">
# <div class="movie-card mc-flex movie-card-0" data-movie-id="640188">
# <div class="mc-poster">
# <a href="https://www.filmaffinity.com/es/film640188.html"><img alt="Hermanos de sangre (Miniserie de TV)" class="lazyload" data-src="https://pics.filmaffinity.com/band_of_brothers-541225951-msmall.jpg" height="" src="https://pics.filmaffinity.com/band_of_brothers-541225951-mtiny.jpg" width="100"/></a>
# </div>
# <div class="mc-info-container">
# <div class="mc-title"><a href="https://www.filmaffinity.com/es/film640188.html" title="Hermanos de sangre">Hermanos de sangre</a></div>
# <div class="d-flex">
# <div class="types-wrapper">
# <span class="type">Miniserie</span> </div>
# <img alt="Estados Unidos" class="nflag" src="/imgs/countries2/US.png"/><span class="mc-year">2001</span>
# </div>
# <div class="mc-director"><div class="credits"><span class="nb"><a href="https://www.filmaffinity.com/es/name.php?name-id=510115519" title="Stephen Ambrose">Stephen Ambrose</a> <i>(Creador)</i>,</span> <span class="nb"><a href="https://www.filmaffinity.com/es/name.php?name-id=759508505" title="David Frankel">David Frankel</a></span> ...</div></div>
# <div class="mc-cast"><div class="credits"><span class="nb"><a href="https://www.filmaffinity.com/es/name.php?name-id=123330839" title="Damian Lewis">Damian Lewis</a>,</span> <span class="nb"><a href="https://www.filmaffinity.com/es/name.php?name-id=416989679" title="Ron Livingston">Ron Livingston</a>,</span> <span class="nb"><a href="https://www.filmaffinity.com/es/name.php?name-id=656159744" title="Scott Grimes">Scott Grimes</a>,</span> <span class="nb"><a href="https://www.filmaffinity.com/es/name.php?name-id=796727207" title="Donnie Wahlberg">Donnie Wahlberg</a>,</span> <span class="nb"><a href="https://www.filmaffinity.com/es/name.php?name-id=755767532" title="Neal McDonough">Neal McDonough</a></span> ...</div></div>
# </div>
# <div class="mc-actions">
# </div>
# <div class="lists-box"></div>
# </div>
# </li>
# <li class="data">
# <div class="avg-rating">8,5</div>
# <div class="rat-count">61.314 <i class="fa fa-simple-user-o-fa"></i></div>
# </li>
# </ul>
# </li>
# <li>
# <ul>
# <li class="position">28</li>
# <li class="content">
# <div class="movie-card mc-flex movie-card-0" data-movie-id="209631">
# <div class="mc-poster">
# <a href="https://www.filmaffinity.com/es/film209631.html"><img alt="Harakiri " class="lazyload" data-src="https://pics.filmaffinity.com/seppuku_harakiri-539847961-msmall.jpg" height="" src="https://pics.filmaffinity.com/seppuku_harakiri-539847961-mtiny.jpg" width="100"/></a>
# </div>
# <div class="mc-info-container">
# <div class="mc-title"><a href="https://www.filmaffinity.com/es/film209631.html" title="Harakiri">Harakiri</a></div>
# <div class="d-flex">
# <img alt="Japón" class="nflag" src="/imgs/countries2/JP.png"/><span class="mc-year">1962</span>
# </div>
# <div class="mc-director"><div class="credits"><span class="nb"><a href="https://www.filmaffinity.com/es/name.php?name-id=267661574" title="Masaki Kobayashi">Masaki Kobayashi</a></span></div></div>
# <div class="mc-cast"><div class="credits"><span class="nb"><a href="https://www.filmaffinity.com/es/name.php?name-id=199879107" title="Tatsuya Nakadai">Tatsuya Nakadai</a>,</span> <span class="nb"><a href="https://www.filmaffinity.com/es/name.php?name-id=468815513" title="Rentarô Mikuni">Rentarô Mikuni</a>,</span> <span class="nb"><a href="https://www.filmaffinity.com/es/name.php?name-id=754122296" title="Akira Ishihama">Akira Ishihama</a>,</span> <span class="nb"><a href="https://www.filmaffinity.com/es/name.php?name-id=200442561" title="Shima Iwashita">Shima Iwashita</a>,</span> <span class="nb"><a href="https://www.filmaffinity.com/es/name.php?name-id=136395504" title="Tetsurô Tanba">Tetsurô Tanba</a></span> ...</div></div>
# </div>
# <div class="mc-actions">
# </div>
# <div class="lists-box"></div>
# </div>
# </li>
# <li class="data">
# <div class="avg-rating">8,5</div>
# <div class="rat-count">14.128 <i class="fa fa-simple-user-o-fa"></i></div>
# </li>
# </ul>
# </li>
# <li>
# <ul>
# <li class="position">29</li>
# <li class="content">
# <div class="movie-card mc-flex movie-card-0" data-movie-id="536488">
# <div class="mc-poster">
# <a href="https://www.filmaffinity.com/es/film536488.html"><img alt="El crepúsculo de los dioses " class="lazyload" data-src="https://pics.filmaffinity.com/sunset_blvd_sunset_boulevard-465026546-msmall.jpg" height="" src="https://pics.filmaffinity.com/sunset_blvd_sunset_boulevard-465026546-mtiny.jpg" width="100"/></a>
# </div>
# <div class="mc-info-container">
# <div class="mc-title"><a href="https://www.filmaffinity.com/es/film536488.html" title="El crepúsculo de los dioses">El crepúsculo de los dioses</a></div>
# <div class="d-flex">
# <img alt="Estados Unidos" class="nflag" src="/imgs/countries2/US.png"/><span class="mc-year">1950</span>
# </div>
# <div class="mc-director"><div class="credits"><span class="nb"><a href="https://www.filmaffinity.com/es/name.php?name-id=174706692" title="Billy Wilder">Billy Wilder</a></span></div></div>
# <div class="mc-cast"><div class="credits"><span class="nb"><a href="https://www.filmaffinity.com/es/name.php?name-id=888079398" title="William Holden">William Holden</a>,</span> <span class="nb"><a href="https://www.filmaffinity.com/es/name.php?name-id=187216649" title="Gloria Swanson">Gloria Swanson</a>,</span> <span class="nb"><a href="https://www.filmaffinity.com/es/name.php?name-id=483497209" title="Erich von Stroheim">Erich von Stroheim</a>,</span> <span class="nb"><a href="https://www.filmaffinity.com/es/name.php?name-id=330852209" title="Nancy Olson">Nancy Olson</a>,</span> <span class="nb"><a href="https://www.filmaffinity.com/es/name.php?name-id=539463855" title="Lloyd Gough">Lloyd Gough</a></span> ...</div></div>
# </div>
# <div class="mc-actions">
# </div>
# <div class="lists-box"></div>
# </div>
# </li>
# <li class="data">
# <div class="avg-rating">8,5</div>
# <div class="rat-count">47.853 <i class="fa fa-simple-user-o-fa"></i></div>
# </li>
# </ul>
# </li>
# <li>
# <ul>
# <li class="position">30</li>
# <li class="content">
# <div class="movie-card mc-flex movie-card-0" data-movie-id="508742">
# <div class="mc-poster">
# <a href="https://www.filmaffinity.com/es/film508742.html"><img alt="Nuestro planeta (Serie de TV)" class="lazyload" data-src="https://pics.filmaffinity.com/our_planet-955486466-msmall.jpg" height="" src="https://pics.filmaffinity.com/our_planet-955486466-mtiny.jpg" width="100"/></a>
# </div>
# <div class="mc-info-container">
# <div class="mc-title"><a href="https://www.filmaffinity.com/es/film508742.html" title="Nuestro planeta">Nuestro planeta</a></div>
# <div class="d-flex">
# <div class="types-wrapper">
# <span class="type">Serie</span><span class="type">Documental</span> </div>
# <img alt="Reino Unido" class="nflag" src="/imgs/countries2/GB.png"/><span class="mc-year">2019</span>
# </div>
# <div class="mc-director"><div class="credits"><span class="nb"><a href="https://www.filmaffinity.com/es/name.php?name-id=390763760" title="David Attenborough">David Attenborough</a> <i>(Creador)</i>,</span> <span class="nb"><a href="https://www.filmaffinity.com/es/name.php?name-id=120099387" title="Adam Chapman">Adam Chapman</a></span> ...</div></div>
# <div class="mc-cast"><div class="credits">Documental, <i> Intervenciones de:</i> <span class="nb"><a href="https://www.filmaffinity.com/es/name.php?name-id=390763760" title="David Attenborough">David Attenborough</a></span></div></div>
# </div>
# <div class="mc-actions">
# </div>
# <div class="lists-box"></div>
# </div>
# </li>
# <li class="data">
# <div class="avg-rating">8,5</div>
# <div class="rat-count">3.169 <i class="fa fa-simple-user-o-fa"></i></div>
# </li>
# </ul>
# </li>
# </ul><!-- cierro main tpl -->
# <div id="load-more-div">
# <div id="load-more-bt" title="Ver más resultados"><i class="fas fa-chevron-down"></i></div>
# <img id="loading" src="/images/loading24.gif" style="display: none;"/>
# </div>
# <div class="bottom-btn-wrapper">
# <a href="https://www.filmaffinity.com/es/best_tops.php">Lo mejor del Top</a>
# <a class="up-button" href="#">volver arriba</a>
# </div>
# <div class="templates">
# <div class="flags-type-translates">
# <div data-flag="full">TODOS</div>
# <div data-flag="movie">películas</div>
# <div data-flag="serie">series</div>
# <div data-flag="documentary">documentales</div>
# <div data-flag="short">cortos</div>
# <div data-flag="animation">animación</div>
# <div data-flag="music">Música</div>
# </div>
# <style>
# .range-slider-fa .custom-range {-webkit-appearance: none; width: 100%; height: 10px; margin-top: 15px; border-radius: 5px; background: #d3d3d3; outline: none; opacity: 0.7; -webkit-transition: .2s; transition: opacity .2s; color: #d3d3d3;}
# .range-slider-fa .custom-range::-webkit-slider-thumb { -webkit-appearance: none; appearance: none; width: 16px; height: 16px; border-radius: 50%; background: #337ab7; cursor: pointer; z-index: 10; pointer-events: auto; }
# .range-slider-fa .custom-range::-moz-range-thumb { width: 16px; height: 16px; border-radius: 50%; background: #337ab7; cursor: pointer; z-index: 10; pointer-events: auto; }
# .range-slider-fa .custom-range::-webkit-slider-runnable-track {background: none;}
# .range-slider-fa .custom-range::-moz-range-track {background: none;}
#
# .range-slider-fa.range-slider-double .inputs {display: grid;  grid-template-rows: max-content 10px; margin-top: 5px; width: 100%; position: relative; background: #d3d3d3; border-radius: 5px; opacity: 0.7; }
# .range-slider-fa.range-slider-double .custom-range {grid-column: 1; grid-row: 2; background: transparent;  font: inherit; margin: 0; pointer-events: none; opacity: 1;}
# .range-slider-fa.range-slider-double .custom-range::webkit-slider-runnable-track {-webkit-appearance: none; height: 100%; width: 100%; }
# .range-slider-fa.range-slider-double .custom-range::-moz-range-track {height: 100%; width: 100%; }
#
#
#
# .range-slider-fa .slider-values {text-align: right;}
# .range-slider-fa .slider-values > div {display: inline-block; font-size: 14px; margin-left: 15px;}
#
# </style>
# <div class="range-slider-templates">
# <div class="range-slider-fa range-slider-simple">
# <div class="slider-values">
# <div class="slider-value"></div>
# </div>
# <div class="inputs">
# <label class="label-name" for=""></label>
# <input class="slider custom-range" max="" min="" name="" type="range" value=""/>
# </div>
# </div>
# <div class="range-slider-fa range-slider-double">
# <div class="slider-values">
# <div class="slider-min-value"></div>
# <div class="sep">-</div>
# <div class="slider-max-value"></div>
# </div>
# <div class="inputs">
# <label class="label-name" for=""></label>
# <input class="slider custom-range" max="" min="" name="" type="range" value=""/>
# <input class="slider custom-range" max="" min="" name="" type="range" value=""/>
# </div>
# </div>
# </div>
# </div>
# </div>
# </main>
# <!-- mt-content-cell -->
# <!-- history-bottom -->
# </div><!-- mt-content-wrapper -->
# </div><!-- main-content-table -->
# </div><!-- cpanel -->
# <div class="cpanel adver-wrapper">
# </div>
# <script>var sc_lg = 0</script>
# <div id="sc-sticky"></div>
# <footer id="bpanel">
# <div style="text-align:center; padding: 10px">
# <a href="https://www.filmaffinity.com/es/faq.php">Preguntas más frecuentes</a>
#         | <a href="https://www.filmaffinity.com/es/private.php">Política de privacidad / condiciones de uso</a>
#         | <a href="#" id="privacy-config-2" onclick="window.__tcfapi('displayConsentUi', 2, function() {} );">Configuración de privacidad</a>
#         | <a href="https://m.filmaffinity.com/es/topgen.php"><strong>Ir a Versión MÓVIL</strong></a>
# </div>
# <div style="text-align:center; padding: 10px 2px">
# <span class="subtext">© 2002-2024 Filmaffinity - Movieaffinity | Filmaffinity es una página de recomendación de películas y series, y es un medio totalmente independiente cuya principal prioridad es la privacidad y seguridad de los datos de sus usuarios.<br/>All Rights Reserved - Todos los derechos reservados</span>
# </div>
# </footer><!-- bpanel -->
# <div id="top-anch">
# <a href="#header-top" title="Ir arriba">
# <img alt="arrow" src="https://www.filmaffinity.com/images/arrow-up2.png"/>
# </a>
# </div>
# <div class="main-search-template">
# <div class="overflow-wrapper">
# <div class="o-container animate__animated animate__fadeInDownBig">
# <div class="close-modal"><i class="fal fa-times-circle"></i></div>
# <div class="top-search-wrapper">
# <div class="sticky-search-wrapper">
# <div class="sticky-search-wrapper">
# <a class="pills-search pills-movies" href="">Título <span class="badge"></span></a>
# <a class="pills-search pills-names" href="">Personas <span class="badge"></span></a>
# <a class="pills-search pills-theaters" href="">Cines <span class="badge"></span></a>
# </div>
# </div>
# <div class="st-wrapper">
# <div class="loader">
# <div></div>
# <div></div>
# <div></div>
# <div></div>
# <div></div>
# <div></div>
# <div></div>
# <div></div>
# <div></div>
# <div></div>
# </div>
# </div>
# <div class="header-search">
# <div class="separator sep-title"><a class="sep" href="">Título</a></div>
# <div class="see-all see-title"><a href="#">Ver todos <i class="far fa-chevron-double-right"></i></a></div>
# </div>
# <ul class="title-ac-wrapper"></ul>
# <div class="header-search">
# <div class="separator sep-name"><a class="sep" href="">Personas</a></div>
# <div class="see-all see-name"><a href="#">Ver todos <i class="far fa-chevron-double-right"></i></a></div>
# </div>
# <ul class="name-ac-wrapper"></ul>
# <div class="header-search">
# <div class="separator sep-theaters"><a class="sep" href="">Cines</a></div>
# <div class="see-all see-theaters"><a href="#">Ver todos <i class="far fa-chevron-double-right"></i></a></div>
# </div>
# <ul class="theaters-ac-wrapper"></ul>
# </div>
# </div><!-- o-container -->
# </div><!-- overflow-wrapper -->
# </div><!-- main-search -->
# <!-- cpanel -->
# </body>
# <!-- Quantcast Tag -->
# <script type="text/javascript">
# window._qevents = window._qevents || [];
#
# (function() {
# var elem = document.createElement('script');
# elem.src = (document.location.protocol == "https:" ? "https://secure" : "http://edge") + ".quantserve.com/quant.js";
# elem.async = true;
# elem.type = "text/javascript";
# var scpt = document.getElementsByTagName('script')[0];
# scpt.parentNode.insertBefore(elem, scpt);
# })();
#
# window._qevents.push({
# qacct:"p-LBBrF-bdAtkuF",
# uid:"__INSERT_EMAIL_HERE__"
# });
# </script>
# <noscript>
# <div style="display:none;">
# <img alt="Quantcast" border="0" height="1" src="//pixel.quantserve.com/pixel/p-LBBrF-bdAtkuF.gif" width="1">
# </img></div>
# </noscript>
# <!-- End Quantcast tag --></html>

# %% [markdown]
# Ahora que hemos aprendido algo de HTML básico, finalmente podemos comenzar a extraer datos de soup. Simplemente escriba un nombre de etiqueta después de soup y un punto (como soup.title), y observe cómo se desarrolla la magia:

# %%
soup.title
# Out:
# <title>Top Filmaffinity: las mejores películas y series de la historia por países - años - género - FilmAffinity</title>

# %%
soup.h1
# Out:
# <h1 id="main-title">Top FilmAffinity</h1>

# %%
soup.h1.get_text()
# Out:
# 'Top FilmAffinity'

# %% [markdown]
# ¿Qué sucede si solo necesita el atributo de un elemento?

# %%
soup.a
# Out:
# <a href="https://www.filmaffinity.com/es/main.html">
# <img alt="logo" src="/images/logo4.png"/>
# <div class="logo-siteloc">España</div>
# </a>

# %%
soup.a['href']
# Out:
# 'https://www.filmaffinity.com/es/main.html'

# %%
print("Sin utilizar método .find()")
print(soup.a)
print("")
print("Utilizando método .find()")
print(soup.find("a"))
# Out:
# Sin utilizar método .find()
# <a href="https://www.filmaffinity.com/es/main.html">
# <img alt="logo" src="/images/logo4.png"/>
# <div class="logo-siteloc">España</div>
# </a>
#
# Utilizando método .find()
# <a href="https://www.filmaffinity.com/es/main.html">
# <img alt="logo" src="/images/logo4.png"/>
# <div class="logo-siteloc">España</div>
# </a>

# %%
soup.find("a").find('img')['src']
# Out:
# '/images/logo4.png'

# %%
soup.find_all('a')
# Out:
# [<a href="https://www.filmaffinity.com/es/main.html">
#  <img alt="logo" src="/images/logo4.png"/>
#  <div class="logo-siteloc">España</div>
#  </a>,
#  <a href="https://www.filmaffinity.com/es/advsearch.php">Búsqueda avanzada <i class="fas fa-angle-double-right"></i></a>,
#  <a class="sign-in" href="https://www.filmaffinity.com/es/login.php"><strong>Iniciar sesión</strong></a>,
#  <a class="register" href="https://www.filmaffinity.com/es/register.php">Registrarse</a>,
#  <a href="https://www.filmaffinity.com/es/topgen.php">Top FA</a>,
#  <a href="https://www.filmaffinity.com/es/rankings.php">Rankings FA</a>,
#  <a href="https://www.filmaffinity.com/es/category.php?id=2024films">Cine 2024</a>,
#  <a href="https://www.filmaffinity.com/es/best_2023.php">Resumen 2023</a>,
#  <a href="https://www.filmaffinity.com/es/calendar-tv.php">Calendario Series</a>,
#  <a href="https://www.filmaffinity.com/es/category.php?id=latest_reviews">Últ. críticas</a>,
#  <a href="https://www.filmaffinity.com/es/category.php?id=TRAILERS">Tráilers</a>,
#  <a href="https://www.filmaffinity.com/es/all_awards.php">Premios</a>,
#  <a href="https://www.filmaffinity.com/es/award-edition.php?edition-id=cannes_2024">Cannes 2024 <span class="tooltip-new">New</span></a>,
#  <a href="https://twitter.com/Filmaffinity" target="_BLANK" title="Sigue a FA en Twitter (60.000 followers)"><i class="fa-brands fa-x-twitter"></i></a>,
#  <a href="https://www.instagram.com/filmaffinity/" target="_BLANK" title="Sigue a FA en Instagram (155.000 followers)"><i class="fab fa-instagram"></i></a>,
#  <a class="more-info" href="https://www.filmaffinity.com/es/fa-international.php"><i class="fas fa-info-circle"></i> Más información</a>,
#  <a class="rate-tours" href="https://www.filmaffinity.com/es/tours.php">Votar los tours</a>,
#  <a class="sign-in" href="https://www.filmaffinity.com/es/login.php">Iniciar sesión</a>,
#  <a href="https://www.filmaffinity.com/es/register.php">Registrarse</a>,
#  <a href="https://www.filmaffinity.com/es/cat_new_th_es.html">Películas en cartelera</a>,
#  <a href="https://www.filmaffinity.com/es/cityTheaters.php">Cines España</a>,
#  <a href="https://www.filmaffinity.com/es/rdcat.php?id=upc_th_es">Próximos estrenos</a>,
#  <a href="https://www.filmaffinity.com/es/cat_new_sa_es.html">Estrenos Blu-ray venta</a>,
#  <a href="https://www.filmaffinity.com/es/rdcat.php?id=upc_sa_es">Próximos Blu-ray venta</a>,
#  <a href="https://www.filmaffinity.com/es/cat_new_re_es.html">Ya para alquilar</a>,
#  <a href="https://www.filmaffinity.com/es/rdcat.php?id=upc_re_es">Próximamente alquiler</a>,
#  <a href="https://www.filmaffinity.com/es/cat_new_netflix.html">Netflix</a>,
#  <a href="https://www.filmaffinity.com/es/rdcat.php?id=upc_netflix">Netflix (próx)</a>,
#  <a href="https://www.filmaffinity.com/es/cat_new_amazon_es.html">Amazon Prime</a>,
#  <a href="https://www.filmaffinity.com/es/cat_new_movistar_f.html">Movistar Plus+ </a>,
#  <a href="https://www.filmaffinity.com/es/cat_upc_movistar_f.html">Movistar Plus+ (próx)</a>,
#  <a href="https://www.filmaffinity.com/es/cat_new_hbo_es.html">HBO Max</a>,
#  <a href="https://www.filmaffinity.com/es/cat_disneyplus.html">Disney+</a>,
#  <a href="https://www.filmaffinity.com/es/cat_new_filmin.html">Filmin</a>,
#  <a href="https://www.filmaffinity.com/es/cat_apple_tv_plus.html">Apple TV+</a>,
#  <a href="https://www.filmaffinity.com/es/cat_skyshowtime.html">SkyShowtime</a>,
#  <a href="https://www.filmaffinity.com/es/cat_new_th_us.html">Estrenos USA</a>,
#  <a href="https://www.filmaffinity.com/es/cat_new_th_uk.html">Estrenos Reino Unido</a>,
#  <a href="https://www.filmaffinity.com/es/cat_new_th_fr.html">Estrenos Francia</a>,
#  <a class="Rankings" href="https://www.filmaffinity.com/es/rankings.php">Todos los rankings</a>,
#  <a href="https://www.filmaffinity.com/es/ranking.php?rn=ranking_fa_movies">El Top 1000 de FA</a>,
#  <a href="https://www.filmaffinity.com/es/boxoffice.php">Taquilla</a>,
#  <a href="https://www.filmaffinity.com/es/trailers.php">Trailers</a>,
#  <a href="https://www.filmaffinity.com/es/latestevideos.php">Últimos trailers</a>,
#  <a href="https://www.filmaffinity.com/es/latestreviews.php">Últimas críticas users</a>,
#  <a href="https://www.filmaffinity.com/es/category.php?id=latest_reviews">Qué dice la crítica</a>,
#  <a href="https://www.filmaffinity.com/es/topics.php">Películas por temas</a>,
#  <a href="https://www.filmaffinity.com/es/movie-groups-all.php">Sagas &amp; Franquicias</a>,
#  <a href="https://www.filmaffinity.com/es/cat_current_tv.html">Series de actualidad</a>,
#  <a href="https://www.filmaffinity.com/es/topgen.php?genres=-DO&amp;chv=1&amp;orderby=avg&amp;movietype=serie%7Conly-serie&amp;country=&amp;fromyear=1874&amp;toyear=2021&amp;ratingcount=3&amp;runtimemin=0&amp;runtimemax=4">Top series</a>,
#  <a href="https://www.filmaffinity.com/es/tour.php?idtour=26">Vota Series de TV</a>,
#  <a href="https://www.filmaffinity.com/es/topgen.php">Top Filmaffinity</a>,
#  <a href="https://www.filmaffinity.com/es/best_tops.php">Lo mejor del TOP</a>,
#  <a href="https://www.filmaffinity.com/es/topcat_new_th_es.html">Top Estrenos</a>,
#  <a href="https://www.filmaffinity.com/es/topcat_new_sa_es.html">Top Estrenos Blu-ray</a>,
#  <a href="https://www.filmaffinity.com/es/listsrank.php">Ranking de listas</a>,
#  <a href="https://www.filmaffinity.com/es/all_awards.php">Premios y Festivales</a>,
#  <a href="https://www.filmaffinity.com/es/oscar_data.php">Todos los Oscar</a>,
#  <a href="https://www.filmaffinity.com/es/best_2023.php">Resumen 2023</a>,
#  <a href="https://www.filmaffinity.com/es/site-guide.php">Acerca de FA</a>,
#  <a href="https://www.filmaffinity.com/es/contact_us.php">Contacto</a>,
#  <a href="#" id="copy-to-clip" title="Copia la URL para compartir">
#  <div class="share-icon" id="copy-to-clip-container"><i class="fas fa-link"></i></div>
#  </a>,
#  <a class="fb-sh" href="https://www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Fwww.filmaffinity.com%2Fes%2Ftopgen.php&amp;t=Top Filmaffinity: las mejores películas y series de la historia por países - años - género" target="_BLANK" title="Comparte en Facebook">
#  <div class="share-icon"><i class="fab fa-facebook-f"></i></div>
#  </a>,
#  <a class="tw-sh" href="https://twitter.com/intent/tweet?text=Top%20Filmaffinity%3A%20las%20mejores%20pel%C3%ADculas%20y%20series%20de%20la%20historia%20por%20pa%C3%ADses%20-%20a%C3%B1os%20-%20g%C3%A9nero en @filmaffinity https%3A%2F%2Fwww.filmaffinity.com%2Fes%2Ftopgen.php" target="_BLANK" title="Comparte en Twitter">
#  <div class="share-icon"><i class="fab fa-twitter"></i></div>
#  </a>,
#  <a class="wh-sh" href="https://api.whatsapp.com/send?text=Top%20Filmaffinity%3A%20las%20mejores%20pel%C3%ADculas%20y%20series%20de%20la%20historia%20por%20pa%C3%ADses%20-%20a%C3%B1os%20-%20g%C3%A9nero en @filmaffinity https%3A%2F%2Fwww.filmaffinity.com%2Fes%2Ftopgen.php" target="_BLANK" title="Comparte en WhatsApp">
#  <div class="share-icon"><i class="fab fa-whatsapp"></i></div>
#  </a>,
#  <a aria-expanded="false" class="btn btn-primary-outline dropdown-toggle" data-bs-toggle="dropdown" href="#" id="dropdownMenuLink" role="button">
#                      Todos los géneros                </a>,
#  <a href="#8"><img alt="Netflix" src="https://images.justwatch.com/icon/207360008/s100" title="Netflix"/><i class="fal fa-check"></i></a>,
#  <a href="#119"><img alt="Amazon Prime Video" src="https://images.justwatch.com/icon/52449861/s100" title="Amazon Prime Video"/><i class="fal fa-check"></i></a>,
#  <a href="#1899"><img alt="Max" src="https://images.justwatch.com/icon/305458112/s100" title="Max"/><i class="fal fa-check"></i></a>,
#  <a href="#384"><img alt="HBO Max" src="https://images.justwatch.com/icon/285237061/s100" title="HBO Max"/><i class="fal fa-check"></i></a>,
#  <a href="#1773"><img alt="SkyShowtime" src="https://images.justwatch.com/icon/300772362/s100" title="SkyShowtime"/><i class="fal fa-check"></i></a>,
#  <a href="#337"><img alt="Disney Plus" src="https://images.justwatch.com/icon/313118777/s100" title="Disney Plus"/><i class="fal fa-check"></i></a>,
#  <a href="#149"><img alt="Movistar Plus" src="https://images.justwatch.com/icon/304905973/s100" title="Movistar Plus"/><i class="fal fa-check"></i></a>,
#  <a href="#350"><img alt="Apple TV Plus" src="https://images.justwatch.com/icon/152862153/s100" title="Apple TV Plus"/><i class="fal fa-check"></i></a>,
#  <a href="#63"><img alt="Filmin" src="https://images.justwatch.com/icon/187161245/s100" title="Filmin"/><i class="fal fa-check"></i></a>,
#  <a href="#64"><img alt="Filmin Plus" src="https://images.justwatch.com/icon/188383996/s100" title="Filmin Plus"/><i class="fal fa-check"></i></a>,
#  <a href="#1796"><img alt="Netflix basic with Ads" src="https://images.justwatch.com/icon/301462744/s100" title="Netflix basic with Ads"/><i class="fal fa-check"></i></a>,
#  <a href="#35"><img alt="Rakuten TV" src="https://images.justwatch.com/icon/128599720/s100" title="Rakuten TV"/><i class="fal fa-check"></i></a>,
#  <a href="#188"><img alt="YouTube Premium" src="https://images.justwatch.com/icon/70189310/s100" title="YouTube Premium"/><i class="fal fa-check"></i></a>,
#  <a href="#283"><img alt="Crunchyroll" src="https://images.justwatch.com/icon/127445869/s100" title="Crunchyroll"/><i class="fal fa-check"></i></a>,
#  <a href="#11"><img alt="MUBI" src="https://images.justwatch.com/icon/164970114/s100" title="MUBI"/><i class="fal fa-check"></i></a>,
#  <a href="#257"><img alt="fuboTV" src="https://images.justwatch.com/icon/124248862/s100" title="fuboTV"/><i class="fal fa-check"></i></a>,
#  <a href="#100"><img alt="GuideDoc" src="https://images.justwatch.com/icon/2625277/s100" title="GuideDoc"/><i class="fal fa-check"></i></a>,
#  <a href="#393"><img alt="FlixOlé" src="https://images.justwatch.com/icon/273964237/s100" title="FlixOlé"/><i class="fal fa-check"></i></a>,
#  <a href="#190"><img alt="Curiosity Stream" src="https://images.justwatch.com/icon/48600036/s100" title="Curiosity Stream"/><i class="fal fa-check"></i></a>,
#  <a href="#456"><img alt="Mitele " src="https://images.justwatch.com/icon/202925890/s100" title="Mitele "/><i class="fal fa-check"></i></a>,
#  <a href="#475"><img alt="DOCSVILLE" src="https://images.justwatch.com/icon/208148387/s100" title="DOCSVILLE"/><i class="fal fa-check"></i></a>,
#  <a href="#194"><img alt="Starz Play Amazon Channel" src="https://images.justwatch.com/icon/241732487/s100" title="Starz Play Amazon Channel"/><i class="fal fa-check"></i></a>,
#  <a href="#534"><img alt="Argo" src="https://images.justwatch.com/icon/242706549/s100" title="Argo"/><i class="fal fa-check"></i></a>,
#  <a href="#546"><img alt="WOW Presents Plus" src="https://images.justwatch.com/icon/243229654/s100" title="WOW Presents Plus"/><i class="fal fa-check"></i></a>,
#  <a href="#551"><img alt="Magellan TV" src="https://images.justwatch.com/icon/243233518/s100" title="Magellan TV"/><i class="fal fa-check"></i></a>,
#  <a href="#554"><img alt="BroadwayHD" src="https://images.justwatch.com/icon/243239329/s100" title="BroadwayHD"/><i class="fal fa-check"></i></a>,
#  <a href="#62"><img alt="Atres Player" src="https://images.justwatch.com/icon/179272126/s100" title="Atres Player"/><i class="fal fa-check"></i></a>,
#  <a href="#444"><img alt="Dekkoo" src="https://images.justwatch.com/icon/202068207/s100" title="Dekkoo"/><i class="fal fa-check"></i></a>,
#  <a href="#567"><img alt="True Story" src="https://images.justwatch.com/icon/244289819/s100" title="True Story"/><i class="fal fa-check"></i></a>,
#  <a href="#569"><img alt="DocAlliance Films" src="https://images.justwatch.com/icon/244290074/s100" title="DocAlliance Films"/><i class="fal fa-check"></i></a>,
#  <a href="#43"><img alt="Starz" src="https://images.justwatch.com/icon/301254735/s100" title="Starz"/><i class="fal fa-check"></i></a>,
#  <a href="#223"><img alt="Hayu" src="https://images.justwatch.com/icon/301318462/s100" title="Hayu"/><i class="fal fa-check"></i></a>,
#  <a href="#524"><img alt="Discovery+" src="https://images.justwatch.com/icon/241126382/s100" title="Discovery+"/><i class="fal fa-check"></i></a>,
#  <a href="#296"><img alt="Hayu Amazon Channel" src="https://images.justwatch.com/icon/241732559/s100" title="Hayu Amazon Channel"/><i class="fal fa-check"></i></a>,
#  <a href="
V"/><i class="fal fa-check"></i></a>,
#  <a href="#1890"><img alt="Hopster Amazon Channel" src="https://images.justwatch.com/icon/304872094/s100" title="Hopster Amazon Channel"/><i class="fal fa-check"></i></a>,
#  <a href="#2"><img alt="Apple TV" src="https://images.justwatch.com/icon/190848813/s100" title="Apple TV"/><i class="fal fa-check"></i></a>,
#  <a href="#3"><img alt="Google Play Movies" src="https://images.justwatch.com/icon/169478387/s100" title="Google Play Movies"/><i class="fal fa-check"></i></a>,
#  <a href="#283"><img alt="Crunchyroll" src="https://images.justwatch.com/icon/127445869/s100" title="Crunchyroll"/><i class="fal fa-check"></i></a>,
#  <a href="#541"><img alt="rtve" src="https://images.justwatch.com/icon/243087006/s100" title="rtve"/><i class="fal fa-check"></i></a>,
#  <a href="#538"><img alt="Plex" src="https://images.justwatch.com/icon/301832745/s100" title="Plex"/><i class="fal fa-check"></i></a>,
#  <a href="#315"><img alt="Hoichoi" src="https://images.justwatch.com/icon/141253805/s100" title="Hoichoi"/><i class="fal fa-check"></i></a>,
#  <a href="#677"><img alt="Eventive" src="https://images.justwatch.com/icon/258768419/s100" title="Eventive"/><i class="fal fa-check"></i></a>,
#  <a href="#1771"><img alt="Takflix" src="https://images.justwatch.com/icon/300757493/s100" title="Takflix"/><i class="fal fa-check"></i></a>,
#  <a href="#1838"><img alt="Tivify" src="https://images.justwatch.com/icon/302542003/s100" title="Tivify"/><i class="fal fa-check"></i></a>,
#  <a href="#1820"><img alt="OneFootball" src="https://images.justwatch.com/icon/301743701/s100" title="OneFootball"/><i class="fal fa-check"></i></a>,
#  <a href="#1908"><img alt="BLAST.tv" src="https://images.justwatch.com/icon/305250213/s100" title="BLAST.tv"/><i class="fal fa-check"></i></a>,
#  <a href="#1813"><img alt="The FA Player" src="https://images.justwatch.com/icon/301624576/s100" title="The FA Player"/><i class="fal fa-check"></i></a>,
#  <a href="#1915"><img alt="NWSL+" src="https://images.justwatch.com/icon/312395858/s100" title="NWSL+"/><i class="fal fa-check"></i></a>,
#  <a href="#616"><img alt="HBO Max Free" src="https://images.justwatch.com/icon/249359407/s100" title="HBO Max Free"/><i class="fal fa-check"></i></a>,
#  <a href="#1789"><img alt="YouTube Sports" src="https://images.justwatch.com/icon/59562423/s100" title="YouTube Sports"/><i class="fal fa-check"></i></a>,
#  <a href="#1886"><img alt="UEFA tv" src="https://images.justwatch.com/icon/304800674/s100" title="UEFA tv"/><i class="fal fa-check"></i></a>,
#  <a href="#2028"><img alt="DFB Play" src="https://images.justwatch.com/icon/311327139/s100" title="DFB Play"/><i class="fal fa-check"></i></a>,
#  <a href="#1934"><img alt="FIFA+" src="https://images.justwatch.com/icon/306585562/s100" title="FIFA+"/><i class="fal fa-check"></i></a>,
#  <a href="#457"><img alt="VIX " src="https://images.justwatch.com/icon/306191612/s100" title="VIX "/><i class="fal fa-check"></i></a>,
#  <a href="#62"><img alt="Atres Player" src="https://images.justwatch.com/icon/179272126/s100" title="Atres Player"/><i class="fal fa-check"></i></a>,
#  <a href="#559"><img alt="Filmzie" src="https://images.justwatch.com/icon/269433194/s100" title="Filmzie"/><i class="fal fa-check"></i></a>,
#  <a href="#300"><img alt="Pluto TV" src="https://images.justwatch.com/icon/312204955/s100" title="Pluto TV"/><i class="fal fa-check"></i></a>,
#  <a href="#
a>,
#  <a href="https://www.filmaffinity.com/es/name.php?name-id=539463855" title="Lloyd Gough">Lloyd Gough</a>,
#  <a href="https://www.filmaffinity.com/es/film508742.html"><img alt="Nuestro planeta (Serie de TV)" class="lazyload" data-src="https://pics.filmaffinity.com/our_planet-955486466-msmall.jpg" height="" src="https://pics.filmaffinity.com/our_planet-955486466-mtiny.jpg" width="100"/></a>,
#  <a href="https://www.filmaffinity.com/es/film508742.html" title="Nuestro planeta">Nuestro planeta</a>,
#  <a href="https://www.filmaffinity.com/es/name.php?name-id=390763760" title="David Attenborough">David Attenborough</a>,
#  <a href="https://www.filmaffinity.com/es/name.php?name-id=120099387" title="Adam Chapman">Adam Chapman</a>,
#  <a href="https://www.filmaffinity.com/es/name.php?name-id=390763760" title="David Attenborough">David Attenborough</a>,
#  <a href="https://www.filmaffinity.com/es/best_tops.php">Lo mejor del Top</a>,
#  <a class="up-button" href="#">volver arriba</a>,
#  <a href="https://www.filmaffinity.com/es/faq.php">Preguntas más frecuentes</a>,
#  <a href="https://www.filmaffinity.com/es/private.php">Política de privacidad / condiciones de uso</a>,
#  <a href="#" id="privacy-config-2" onclick="window.__tcfapi('displayConsentUi', 2, function() {} );">Configuración de privacidad</a>,
#  <a href="https://m.filmaffinity.com/es/topgen.php"><strong>Ir a Versión MÓVIL</strong></a>,
#  <a href="#header-top" title="Ir arriba">
#  <img alt="arrow" src="https://www.filmaffinity.com/images/arrow-up2.png"/>
#  </a>,
#  <a class="pills-search pills-movies" href="">Título <span class="badge"></span></a>,
#  <a class="pills-search pills-names" href="">Personas <span class="badge"></span></a>,
#  <a class="pills-search pills-theaters" href="">Cines <span class="badge"></span></a>,
#  <a class="sep" href="">Título</a>,
#  <a href="#">Ver todos <i class="far fa-chevron-double-right"></i></a>,
#  <a class="sep" href="">Personas</a>,
#  <a href="#">Ver todos <i class="far fa-chevron-double-right"></i></a>,
#  <a class="sep" href="">Cines</a>,
#  <a href="#">Ver todos <i class="far fa-chevron-double-right"></i></a>]

# %%
all_a = soup.find_all('a')
for a in all_a[:5]:
    print(a)
# Out:
# <a href="https://www.filmaffinity.com/es/main.html">
# <img alt="logo" src="/images/logo4.png"/>
# <div class="logo-siteloc">España</div>
# </a>
# <a href="https://www.filmaffinity.com/es/advsearch.php">Búsqueda avanzada <i class="fas fa-angle-double-right"></i></a>
# <a class="sign-in" href="https://www.filmaffinity.com/es/login.php"><strong>Iniciar sesión</strong></a>
# <a class="register" href="https://www.filmaffinity.com/es/register.php">Registrarse</a>
# <a href="https://www.filmaffinity.com/es/topgen.php">Top FA</a>

# %%
all_a = soup.find_all('a')
for a in all_a[:5]:
    print(a.get_text())
# Out:
# España
#
# Búsqueda avanzada
# Iniciar sesión
# Registrarse
# Top FA

# %%
all_a = soup.find_all('a')
for a in all_a[:5]:
    print(a['href'])
# Out:
# https://www.filmaffinity.com/es/main.html
# https://www.filmaffinity.com/es/advsearch.php
# https://www.filmaffinity.com/es/login.php
# https://www.filmaffinity.com/es/register.php
# https://www.filmaffinity.com/es/topgen.php

# %% [markdown]
# # Obtener textos menú cabecera
# Top FA| Rankings FA| Año 2023| Calendario Series| Últ. críticas| Tráilers| Premios
#
# * Obtén los textos con find_all y un bucle
# * Obtén los links con find_all y un bucle
# * Almacena la información en un dataframe

# %%
# /html/body/header/div[2]/div/ul/li[3]/a

# %%
soup.find("ul", id="awardsmenu").find_all('a')
# Out:
# [<a href="https://www.filmaffinity.com/es/topgen.php">Top FA</a>,
#  <a href="https://www.filmaffinity.com/es/rankings.php">Rankings FA</a>,
#  <a href="https://www.filmaffinity.com/es/category.php?id=2024films">Cine 2024</a>,
#  <a href="https://www.filmaffinity.com/es/best_2023.php">Resumen 2023</a>,
#  <a href="https://www.filmaffinity.com/es/calendar-tv.php">Calendario Series</a>,
#  <a href="https://www.filmaffinity.com/es/category.php?id=latest_reviews">Últ. críticas</a>,
#  <a href="https://www.filmaffinity.com/es/category.php?id=TRAILERS">Tráilers</a>,
#  <a href="https://www.filmaffinity.com/es/all_awards.php">Premios</a>,
#  <a href="https://www.filmaffinity.com/es/award-edition.php?edition-id=cannes_2024">Cannes 2024 <span class="tooltip-new">New</span></a>]

# %%
for enlace in soup.find("ul", id="awardsmenu").find_all('a'):
    print(enlace.get_text())
    print(enlace['href'])
# Out:
# Top FA
# https://www.filmaffinity.com/es/topgen.php
# Rankings FA
# https://www.filmaffinity.com/es/rankings.php
# Cine 2024
# https://www.filmaffinity.com/es/category.php?id=2024films
# Resumen 2023
# https://www.filmaffinity.com/es/best_2023.php
# Calendario Series
# https://www.filmaffinity.com/es/calendar-tv.php
# Últ. críticas
# https://www.filmaffinity.com/es/category.php?id=latest_reviews
# Tráilers
# https://www.filmaffinity.com/es/category.php?id=TRAILERS
# Premios
# https://www.filmaffinity.com/es/all_awards.php
# Cannes 2024 New
# https://www.filmaffinity.com/es/award-edition.php?edition-id=cannes_2024

# %%
menu_dict = {"Nombre": [],
             "Enlace": []}

for enlace in soup.find("ul", id="awardsmenu").find_all('a'):
    menu_dict['Nombre'].append(enlace.get_text())
    menu_dict['Enlace'].append(enlace['href'])

df = pd.DataFrame(menu_dict)
df.to_csv("enlaces_menus.csv")
df
# Out:
#               Nombre  \
# 0             Top FA
# 1        Rankings FA
# 2          Cine 2024
# 3       Resumen 2023
# 4  Calendario Series
# 5      Últ. críticas
# 6           Tráilers
# 7            Premios
# 8    Cannes 2024 New
#
#                                                                      Enlace
# 0                                https://www.filmaffinity.com/es/topgen.php
# 1                              https://www.filmaffinity.com/es/rankings.php
# 2                 https://www.filmaffinity.com/es/category.php?id=2024films
# 3                             https://www.filmaffinity.com/es/best_2023.php
# 4                           https://www.filmaffinity.com/es/calendar-tv.php
# 5            https://www.filmaffinity.com/es/category.php?id=latest_reviews
# 6                  https://www.filmaffinity.com/es/category.php?id=TRAILERS
# 7                            https://www.filmaffinity.com/es/all_awards.php
# 8  https://www.filmaffinity.com/es/award-edition.php?edition-id=cannes_2024

# %% [markdown]
# # Obtener películas y nota
#
# * Obtén los títulos de las top 10 películas
# * Obtén el rating de las top 10 películas
# * Almacena la información en un dataframe

# %%
# /html/body/div[2]/div/div/main/div[2]/ul/li[1]/ul/li[2]/div/div[2]/div[1]/a

# %%
soup.find('div', class_="mc-title").find("a").get_text()
# Out:
# 'El padrino'

# %%
soup.find_all('div', class_="mc-title")
# Out:
# [<div class="mc-title"><a href="https://www.filmaffinity.com/es/film809297.html" title="El padrino">El padrino</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film107937.html" title="Planeta Tierra II">Planeta Tierra II</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film730528.html" title="El padrino. Parte II">El padrino. Parte II</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film399474.html" title="The Wire (Bajo escucha)">The Wire (Bajo escucha)</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film489970.html" title="Breaking Bad">Breaking Bad</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film518489.html" title="Planeta azul II">Planeta azul II</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film601451.html" title="Cosmos">Cosmos</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film695552.html" title="Doce hombres sin piedad">Doce hombres sin piedad</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film661074.html" title="Cosmos: A Space-Time Odyssey">Cosmos: A Space-Time Odyssey</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film656153.html" title="La lista de Schindler">La lista de Schindler</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film667376.html" title="Testigo de cargo">Testigo de cargo</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film356260.html" title="Siete mundos, un planeta">Siete mundos, un planeta</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film221477.html" title="Apocalipsis: La Segunda Guerra Mundial">Apocalipsis: La Segunda Guerra Mundial</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film750301.html" title="Luces de la ciudad">Luces de la ciudad</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film161026.html" title="Cadena perpetua">Cadena perpetua</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film372160.html" title="Los Simpson">Los Simpson</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film674611.html" title="Ingeniería Romana">Ingeniería Romana</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film155010.html" title="El gran dictador">El gran dictador</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film160882.html" title="Pulp Fiction">Pulp Fiction</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film726746.html" title="Tiempos modernos">Tiempos modernos</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film934135.html" title="Planeta Tierra">Planeta Tierra</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film385464.html" title="El golpe">El golpe</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film874956.html" title="Juego de Tronos">Juego de Tronos</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film402150.html" title="Los Soprano">Los Soprano</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film883966.html" title="The Beatles Anthology">The Beatles Anthology</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film684718.html" title="Ser o no ser">Ser o no ser</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film640188.html" title="Hermanos de sangre">Hermanos de sangre</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film209631.html" title="Harakiri">Harakiri</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film536488.html" title="El crepúsculo de los dioses">El crepúsculo de los dioses</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film508742.html" title="Nuestro planeta">Nuestro planeta</a></div>]

# %%
# /html/body/div[2]/div/div/main/div[2]/ul/li[1]/ul/li[3]/div[1]

# %%
soup.find_all('div', class_= "avg-rating")
# Out:
# [<div class="avg-rating">9,0</div>,
#  <div class="avg-rating">8,9</div>,
#  <div class="avg-rating">8,9</div>,
#  <div class="avg-rating">8,8</div>,
#  <div class="avg-rating">8,8</div>,
#  <div class="avg-rating">8,8</div>,
#  <div class="avg-rating">8,8</div>,
#  <div class="avg-rating">8,7</div>,
#  <div class="avg-rating">8,6</div>,
#  <div class="avg-rating">8,6</div>,
#  <div class="avg-rating">8,6</div>,
#  <div class="avg-rating">8,6</div>,
#  <div class="avg-rating">8,6</div>,
#  <div class="avg-rating">8,6</div>,
#  <div class="avg-rating">8,6</div>,
#  <div class="avg-rating">8,6</div>,
#  <div class="avg-rating">8,6</div>,
#  <div class="avg-rating">8,6</div>,
#  <div class="avg-rating">8,6</div>,
#  <div class="avg-rating">8,6</div>,
#  <div class="avg-rating">8,5</div>,
#  <div class="avg-rating">8,5</div>,
#  <div class="avg-rating">8,5</div>,
#  <div class="avg-rating">8,5</div>,
#  <div class="avg-rating">8,5</div>,
#  <div class="avg-rating">8,5</div>,
#  <div class="avg-rating">8,5</div>,
#  <div class="avg-rating">8,5</div>,
#  <div class="avg-rating">8,5</div>,
#  <div class="avg-rating">8,5</div>]

# %%
lista_divs_titulo = soup.find_all("div", class_= "mc-title")
lista_divs_titulo
# Out:
# [<div class="mc-title"><a href="https://www.filmaffinity.com/es/film809297.html" title="El padrino">El padrino</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film107937.html" title="Planeta Tierra II">Planeta Tierra II</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film730528.html" title="El padrino. Parte II">El padrino. Parte II</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film399474.html" title="The Wire (Bajo escucha)">The Wire (Bajo escucha)</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film489970.html" title="Breaking Bad">Breaking Bad</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film518489.html" title="Planeta azul II">Planeta azul II</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film601451.html" title="Cosmos">Cosmos</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film695552.html" title="Doce hombres sin piedad">Doce hombres sin piedad</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film661074.html" title="Cosmos: A Space-Time Odyssey">Cosmos: A Space-Time Odyssey</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film656153.html" title="La lista de Schindler">La lista de Schindler</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film667376.html" title="Testigo de cargo">Testigo de cargo</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film356260.html" title="Siete mundos, un planeta">Siete mundos, un planeta</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film221477.html" title="Apocalipsis: La Segunda Guerra Mundial">Apocalipsis: La Segunda Guerra Mundial</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film750301.html" title="Luces de la ciudad">Luces de la ciudad</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film161026.html" title="Cadena perpetua">Cadena perpetua</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film372160.html" title="Los Simpson">Los Simpson</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film674611.html" title="Ingeniería Romana">Ingeniería Romana</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film155010.html" title="El gran dictador">El gran dictador</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film160882.html" title="Pulp Fiction">Pulp Fiction</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film726746.html" title="Tiempos modernos">Tiempos modernos</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film934135.html" title="Planeta Tierra">Planeta Tierra</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film385464.html" title="El golpe">El golpe</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film874956.html" title="Juego de Tronos">Juego de Tronos</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film402150.html" title="Los Soprano">Los Soprano</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film883966.html" title="The Beatles Anthology">The Beatles Anthology</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film684718.html" title="Ser o no ser">Ser o no ser</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film640188.html" title="Hermanos de sangre">Hermanos de sangre</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film209631.html" title="Harakiri">Harakiri</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film536488.html" title="El crepúsculo de los dioses">El crepúsculo de los dioses</a></div>,
#  <div class="mc-title"><a href="https://www.filmaffinity.com/es/film508742.html" title="Nuestro planeta">Nuestro planeta</a></div>]

# %%
lista_divs_ratings = soup.find_all('div', class_= "avg-rating")
lista_divs_ratings
# Out:
# [<div class="avg-rating">9,0</div>,
#  <div class="avg-rating">8,9</div>,
#  <div class="avg-rating">8,9</div>,
#  <div class="avg-rating">8,8</div>,
#  <div class="avg-rating">8,8</div>,
#  <div class="avg-rating">8,8</div>,
#  <div class="avg-rating">8,8</div>,
#  <div class="avg-rating">8,7</div>,
#  <div class="avg-rating">8,6</div>,
#  <div class="avg-rating">8,6</div>,
#  <div class="avg-rating">8,6</div>,
#  <div class="avg-rating">8,6</div>,
#  <div class="avg-rating">8,6</div>,
#  <div class="avg-rating">8,6</div>,
#  <div class="avg-rating">8,6</div>,
#  <div class="avg-rating">8,6</div>,
#  <div class="avg-rating">8,6</div>,
#  <div class="avg-rating">8,6</div>,
#  <div class="avg-rating">8,6</div>,
#  <div class="avg-rating">8,6</div>,
#  <div class="avg-rating">8,5</div>,
#  <div class="avg-rating">8,5</div>,
#  <div class="avg-rating">8,5</div>,
#  <div class="avg-rating">8,5</div>,
#  <div class="avg-rating">8,5</div>,
#  <div class="avg-rating">8,5</div>,
#  <div class="avg-rating">8,5</div>,
#  <div class="avg-rating">8,5</div>,
#  <div class="avg-rating">8,5</div>,
#  <div class="avg-rating">8,5</div>]

# %%
pd.DataFrame({"Titulo": [x.find('a').get_text() for x in lista_divs_titulo[:10]],
              "Rating": [x.get_text() for x in lista_divs_ratings[:10]]})
# Out:
#                          Titulo Rating
# 0                    El padrino    9,0
# 1             Planeta Tierra II    8,9
# 2          El padrino. Parte II    8,9
# 3       The Wire (Bajo escucha)    8,8
# 4                  Breaking Bad    8,8
# 5               Planeta azul II    8,8
# 6                        Cosmos    8,8
# 7       Doce hombres sin piedad    8,7
# 8  Cosmos: A Space-Time Odyssey    8,6
# 9         La lista de Schindler    8,6

# %% [markdown]
# # Scrapy
#
# [Scrapy](https://scrapy.org/) es una librería destinada a construir arañas (crawlers o web spiders) para navegar la red saltando entre páginas y enlaces para captar toda la información posible.

# %%
#!pip install scrapy

# %% [markdown]
# Probaremos con una página de frases conocidas (https://quotes.toscrape.com) de las que sacar la información para evitar problemas. Deberemos crear un proyecto:

# %%
# !scrapy startproject quotes
# Out:
# New Scrapy project 'quotes', using template directory '/home/iraitz/TheBridge/Otros/TheBridge_DSPT/.venv/lib/python3.10/site-packages/scrapy/templates/project', created in:
#     /home/iraitz/TheBridge/Otros/TheBridge_DSPT/2-Data Analysis/5-Fuentes de datos/Webscrapping/Teoría/quotes
#
# You can start your first spider with:
#     cd quotes
#     scrapy genspider example example.com

# %% [markdown]
# Y ahora insertar nuestra araña en el directorio _spiders_ de este

# %%
# %%file quotes/quotes/spiders/quotes_spyder.py

from pathlib import Path

import scrapy

class QuotesSpider(scrapy.Spider):
    name = "quotes"
    start_urls = [
        "https://quotes.toscrape.com/page/1/",
        "https://quotes.toscrape.com/page/2/",
    ]

    def parse(self, response):
        page = response.url.split("/")[-2]
        filename = f"quotes-{page}.html"
        Path(filename).write_bytes(response.body)
        self.log(f"Saved file {filename}")
# Out:
# Writing quotes/quotes/spiders/quotes_spyder.py

# %%
import os
os.chdir("quotes")

# %%
# !scrapy crawl quotes
# Out:
# 2024-05-25 20:49:47 [scrapy.utils.log] INFO: Scrapy 2.11.2 started (bot: quotes)
# 2024-05-25 20:49:47 [scrapy.utils.log] INFO: Versions: lxml 5.2.2.0, libxml2 2.12.6, cssselect 1.2.0, parsel 1.9.1, w3lib 2.1.2, Twisted 24.3.0, Python 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0], pyOpenSSL 24.1.0 (OpenSSL 3.2.1 30 Jan 2024), cryptography 42.0.7, Platform Linux-6.5.0-35-generic-x86_64-with-glibc2.35
# 2024-05-25 20:49:47 [scrapy.addons] INFO: Enabled addons:
# []
# 2024-05-25 20:49:47 [asyncio] DEBUG: Using selector: EpollSelector
# 2024-05-25 20:49:47 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2024-05-25 20:49:47 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.unix_events._UnixSelectorEventLoop
# 2024-05-25 20:49:47 [scrapy.extensions.telnet] INFO: Telnet Password: 62d827b1b7faa277
# 2024-05-25 20:49:47 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2024-05-25 20:49:47 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'quotes',
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'quotes.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['quotes.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor'}
# 2024-05-25 20:49:47 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2024-05-25 20:49:47 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2024-05-25 20:49:47 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2024-05-25 20:49:47 [scrapy.core.engine] INFO: Spider opened
# 2024-05-25 20:49:47 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-05-25 20:49:47 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2024-05-25 20:49:48 [scrapy.core.engine] DEBUG: Crawled (404) <GET https://quotes.toscrape.com/robots.txt> (referer: None)
# 2024-05-25 20:49:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://quotes.toscrape.com/page/1/> (referer: None)
# 2024-05-25 20:49:48 [quotes] DEBUG: Saved file quotes-1.html
# 2024-05-25 20:49:48 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://quotes.toscrape.com/page/2/> (referer: None)
# 2024-05-25 20:49:48 [quotes] DEBUG: Saved file quotes-2.html
# 2024-05-25 20:49:48 [scrapy.core.engine] INFO: Closing spider (finished)
# 2024-05-25 20:49:48 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 684,
#  'downloader/request_count': 3,
#  'downloader/request_method_count/GET': 3,
#  'downloader/response_bytes': 25556,
#  'downloader/response_count': 3,
#  'downloader/response_status_count/200': 2,
#  'downloader/response_status_count/404': 1,
#  'elapsed_time_seconds': 1.282528,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2024, 5, 25, 18, 49, 48, 926874, tzinfo=datetime.timezone.utc),
#  'log_count/DEBUG': 8,
#  'log_count/INFO': 10,
#  'memusage/max': 90558464,
#  'memusage/startup': 90558464,
#  'response_received_count': 3,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/404': 1,
#  'scheduler/dequeued': 2,
#  'scheduler/dequeued/memory': 2,
#  'scheduler/enqueued': 2,
#  'scheduler/enqueued/memory': 2,
#  'start_time': datetime.datetime(2024, 5, 25, 18, 49, 47, 644346, tzinfo=datetime.timezone.utc)}
# 2024-05-25 20:49:48 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# Veremos que este código genera la extracción del código fuente de la página web.
