# %% [markdown]
# # Northwind
#
# Existe un ejemplo clásico de un negocio de venta de productos conocido como Northwind. Originalmente diseñado por Microsoft para educar a la gente sobre el uso de access, nosotros emplearemos este ejemplo para ilustrar cómo funcionaría una base de datos operacional y familiarizarnos con la sintaxis SQL.
#
# https://en.wikiversity.org/wiki/Database_Examples/Northwind/SQLite

# %%
import sqlite3

# Connect to the DB
conn = sqlite3.connect("northwind.db")
c = conn.cursor()

with open("northwind_script.sql", 'r') as script:
    lines = script.readlines()

c.execute("""PRAGMA foreign_keys = ON;""")
c.executescript("".join(lines));

# %%
c.execute("""SELECT name FROM sqlite_master WHERE type='table';""").fetchall()
# Out:
# [('Categories',),
#  ('sqlite_sequence',),
#  ('Customers',),
#  ('Employees',),
#  ('Shippers',),
#  ('Suppliers',),
#  ('Products',),
#  ('Orders',),
#  ('OrderDetails',)]

# %% [markdown]
# [SQLAlchemy](https://www.sqlalchemy.org/) es una solución que nos permite abstraernos de las particularidades de cada proveedor, ya que el habla el dialecto SQL necesario. Esto compaginado con Pandas nos permite realizar todas las operaciones anteriores siempre trabajando con un DataFrame a la hora de devolver los resultados.
#
# Podemos trabajar con distintos motores, empleando las mismas operaciones cada vez:
#
# * [MySQL](https://docs.sqlalchemy.org/en/20/dialects/mysql.html)
# * [PostgreSQL](https://docs.sqlalchemy.org/en/20/dialects/postgresql.html)
# * [Oracle](https://docs.sqlalchemy.org/en/20/dialects/oracle.html)
# * [MS SQL Server](https://docs.sqlalchemy.org/en/20/dialects/mssql.html)

# %%
# !pip install sqlalchemy

# %% [markdown]
# Creamos el motor de conexión.

# %%
from sqlalchemy import create_engine

engine = create_engine('sqlite:///northwind.db', echo=False)

# %% [markdown]
# Y dándoselo como parámetro a pandas, podemos obtener la información de una tabla directamente.

# %%
import pandas as pd

employee_df = pd.read_sql_table("Employees", con=engine)
employee_df
# Out:
#    EmployeeID   LastName FirstName  BirthDate        Photo  \
# 0           1    Davolio     Nancy 1968-12-08   EmpID1.pic
# 1           2     Fuller    Andrew 1952-02-19   EmpID2.pic
# 2           3  Leverling     Janet 1963-08-30   EmpID3.pic
# 3           4    Peacock  Margaret 1958-09-19   EmpID4.pic
# 4           5   Buchanan    Steven 1955-03-04   EmpID5.pic
# 5           6     Suyama   Michael 1963-07-02   EmpID6.pic
# 6           7       King    Robert 1960-05-29   EmpID7.pic
# 7           8   Callahan     Laura 1958-01-09   EmpID8.pic
# 8           9  Dodsworth      Anne 1969-07-02   EmpID9.pic
# 9          10       West      Adam 1928-09-19  EmpID10.pic
#
#                                                Notes
# 0  Education includes a BA in psychology from Col...
# 1  Andrew received his BTS commercial and a Ph.D....
# 2  Janet has a BS degree in chemistry from Boston...
# 3  Margaret holds a BA in English literature from...
# 4  Steven Buchanan graduated from St. Andrews Uni...
# 5  Michael is a graduate of Sussex University (MA...
# 6  Robert King served in the Peace Corps and trav...
# 7  Laura received a BA in psychology from the Uni...
# 8  Anne has a BA degree in English from St. Lawre...
# 9                                       An old chum.

# %% [markdown]
# SQLAlchemy permite abstraernos ya que este sistema el que monta las consultas por nosotros dada una conexión. Si explicitamos la consulta usando las funciones de SQLAlchemy nos permite poder cambiar automáticamente entre un dialecto y otro.

# %%
from sqlalchemy import select, text, column

stmt = select(text("FirstName")).where(column("EmployeeID") == 1)
print(stmt)
# Out:
# SELECT FirstName
# WHERE "EmployeeID" = :EmployeeID_1

# %% [markdown]
# Nosotros seguiremos empleando consultas dado que queremos ahondar en este lenguaje, pero echadle un vistazo a la [documentación](https://docs.sqlalchemy.org/en/20/tutorial/data_select.html).

# %%
import pandas as pd

connection = engine.connect()
employee_df = pd.read_sql('SELECT * FROM Employees', con=connection)
employee_df
# Out:
#    EmployeeID   LastName FirstName   BirthDate        Photo  \
# 0           1    Davolio     Nancy  1968-12-08   EmpID1.pic
# 1           2     Fuller    Andrew  1952-02-19   EmpID2.pic
# 2           3  Leverling     Janet  1963-08-30   EmpID3.pic
# 3           4    Peacock  Margaret  1958-09-19   EmpID4.pic
# 4           5   Buchanan    Steven  1955-03-04   EmpID5.pic
# 5           6     Suyama   Michael  1963-07-02   EmpID6.pic
# 6           7       King    Robert  1960-05-29   EmpID7.pic
# 7           8   Callahan     Laura  1958-01-09   EmpID8.pic
# 8           9  Dodsworth      Anne  1969-07-02   EmpID9.pic
# 9          10       West      Adam  1928-09-19  EmpID10.pic
#
#                                                Notes
# 0  Education includes a BA in psychology from Col...
# 1  Andrew received his BTS commercial and a Ph.D....
# 2  Janet has a BS degree in chemistry from Boston...
# 3  Margaret holds a BA in English literature from...
# 4  Steven Buchanan graduated from St. Andrews Uni...
# 5  Michael is a graduate of Sussex University (MA...
# 6  Robert King served in the Peace Corps and trav...
# 7  Laura received a BA in psychology from the Uni...
# 8  Anne has a BA degree in English from St. Lawre...
# 9                                       An old chum.

# %% [markdown]
# De este modo podemos realizar acciones más elaboradas, que sea la base de datos la que realice las operaciones y obtener los resultados cómodamente en un dataframe.

# %%
query = """
SELECT COUNT(*) AS employee_count
FROM Employees  """
pd.read_sql(query, con=connection)
# Out:
#    employee_count
# 0              10

# %%
query = """
SELECT BirthDate, typeof(BirthDate)
FROM Employees """
pd.read_sql(query, con=connection)
# Out:
#     BirthDate typeof(BirthDate)
# 0  1968-12-08              text
# 1  1952-02-19              text
# 2  1963-08-30              text
# 3  1958-09-19              text
# 4  1955-03-04              text
# 5  1963-07-02              text
# 6  1960-05-29              text
# 7  1958-01-09              text
# 8  1969-07-02              text
# 9  1928-09-19              text

# %% [markdown]
# Como veis la fecha está en formato texto, habrá que hacer algún tipo de conversión para poder hacer cálculos con este dato.

# %%
import datetime

today = datetime.datetime.today().strftime("%Y-%m-%d")
today
# Out:
# '2024-05-23'

# %% [markdown]
# Datetime es el comando en SQLite que nos permite convertir una cadena de texto a la fecha que representa.

# %%
query = f"""
SELECT *, datetime('{today}') - datetime(birthdate) as Age
FROM Employees """
pd.read_sql(query, con=connection)
# Out:
#    EmployeeID   LastName FirstName   BirthDate        Photo  \
# 0           1    Davolio     Nancy  1968-12-08   EmpID1.pic
# 1           2     Fuller    Andrew  1952-02-19   EmpID2.pic
# 2           3  Leverling     Janet  1963-08-30   EmpID3.pic
# 3           4    Peacock  Margaret  1958-09-19   EmpID4.pic
# 4           5   Buchanan    Steven  1955-03-04   EmpID5.pic
# 5           6     Suyama   Michael  1963-07-02   EmpID6.pic
# 6           7       King    Robert  1960-05-29   EmpID7.pic
# 7           8   Callahan     Laura  1958-01-09   EmpID8.pic
# 8           9  Dodsworth      Anne  1969-07-02   EmpID9.pic
# 9          10       West      Adam  1928-09-19  EmpID10.pic
#
#                                                Notes  Age
# 0  Education includes a BA in psychology from Col...   56
# 1  Andrew received his BTS commercial and a Ph.D....   72
# 2  Janet has a BS degree in chemistry from Boston...   61
# 3  Margaret holds a BA in English literature from...   66
# 4  Steven Buchanan graduated from St. Andrews Uni...   69
# 5  Michael is a graduate of Sussex University (MA...   61
# 6  Robert King served in the Peace Corps and trav...   64
# 7  Laura received a BA in psychology from the Uni...   66
# 8  Anne has a BA degree in English from St. Lawre...   55
# 9                                       An old chum.   96

# %% [markdown]
# También podemos emplear estas operaciones para filtrar bajo la cláusula `WHERE`

# %%
query = f"""
SELECT *
FROM Employees 
WHERE datetime('{today}') - datetime(birthdate) > 65"""
retired_df = pd.read_sql(query, con=connection)
retired_df
# Out:
#    EmployeeID  LastName FirstName   BirthDate        Photo  \
# 0           2    Fuller    Andrew  1952-02-19   EmpID2.pic
# 1           4   Peacock  Margaret  1958-09-19   EmpID4.pic
# 2           5  Buchanan    Steven  1955-03-04   EmpID5.pic
# 3           8  Callahan     Laura  1958-01-09   EmpID8.pic
# 4          10      West      Adam  1928-09-19  EmpID10.pic
#
#                                                Notes
# 0  Andrew received his BTS commercial and a Ph.D....
# 1  Margaret holds a BA in English literature from...
# 2  Steven Buchanan graduated from St. Andrews Uni...
# 3  Laura received a BA in psychology from the Uni...
# 4                                       An old chum.

# %% [markdown]
# Así nos quedamos con los datos que nos interesan y podemos llevárnoslos a otra tabla.

# %%
retired_df.to_sql(name='Retired', con=engine)
# Out:
# 5

# %%
c.execute("""SELECT name FROM sqlite_master WHERE type='table';""").fetchall()
# Out:
# [('Categories',),
#  ('sqlite_sequence',),
#  ('Customers',),
#  ('Employees',),
#  ('Shippers',),
#  ('Suppliers',),
#  ('Products',),
#  ('Orders',),
#  ('OrderDetails',),
#  ('Retired',)]

# %%
query = """
SELECT FirstName, LastName
FROM Employees 
WHERE Notes LIKE '%Sussex%' """
pd.read_sql(query, con=connection)
# Out:
#   FirstName LastName
# 0   Michael   Suyama

# %%
query = """
SELECT *
FROM Employees e
INNER JOIN Orders o ON o.EmployeeID = e.EmployeeID"""
pd.read_sql(query, con=connection)
# Out:
#      EmployeeID   LastName FirstName   BirthDate       Photo  \
# 0             5   Buchanan    Steven  1955-03-04  EmpID5.pic
# 1             6     Suyama   Michael  1963-07-02  EmpID6.pic
# 2             4    Peacock  Margaret  1958-09-19  EmpID4.pic
# 3             3  Leverling     Janet  1963-08-30  EmpID3.pic
# 4             4    Peacock  Margaret  1958-09-19  EmpID4.pic
# ..          ...        ...       ...         ...         ...
# 191           6     Suyama   Michael  1963-07-02  EmpID6.pic
# 192           4    Peacock  Margaret  1958-09-19  EmpID4.pic
# 193           3  Leverling     Janet  1963-08-30  EmpID3.pic
# 194           3  Leverling     Janet  1963-08-30  EmpID3.pic
# 195           8   Callahan     Laura  1958-01-09  EmpID8.pic
#
#                                                  Notes  OrderID  CustomerID  \
# 0    Steven Buchanan graduated from St. Andrews Uni...    10248          90
# 1    Michael is a graduate of Sussex University (MA...    10249          81
# 2    Margaret holds a BA in English literature from...    10250          34
# 3    Janet has a BS degree in chemistry from Boston...    10251          84
# 4    Margaret holds a BA in English literature from...    10252          76
# ..                                                 ...      ...         ...
# 191  Michael is a graduate of Sussex University (MA...    10439          51
# 192  Margaret holds a BA in English literature from...    10440          71
# 193  Janet has a BS degree in chemistry from Boston...    10441          55
# 194  Janet has a BS degree in chemistry from Boston...    10442          20
# 195  Laura received a BA in psychology from the Uni...    10443          66
#
#      EmployeeID   OrderDate  ShipperID
# 0             5  1996-07-04          3
# 1             6  1996-07-05          1
# 2             4  1996-07-08          2
# 3             3  1996-07-08          1
# 4             4  1996-07-09          2
# ..          ...         ...        ...
# 191           6  1997-02-07          3
# 192           4  1997-02-10          2
# 193           3  1997-02-10          2
# 194           3  1997-02-11          2
# 195           8  1997-02-12          1
#
# [196 rows x 11 columns]

# %%
query = """
SELECT o.EmployeeID, e.FirstName, count(*) AS Ventas
FROM Employees e
INNER JOIN Orders o ON o.EmployeeID = e.EmployeeID
GROUP BY o.EmployeeID
ORDER BY Ventas DESC"""
pd.read_sql(query, con=connection)
# Out:
#    EmployeeID FirstName  Ventas
# 0           4  Margaret      40
# 1           3     Janet      31
# 2           1     Nancy      29
# 3           8     Laura      27
# 4           2    Andrew      20
# 5           6   Michael      18
# 6           7    Robert      14
# 7           5    Steven      11
# 8           9      Anne       6

# %% [markdown]
# # Indices
#
# Los índices nos permiten preparar los datos de ciertos campos por los que preguntemos habitualmente en los filtros. Así, en lugar de mirar la tabla entera en busca de aquellas filas que contengan la información deseada, podremos consultar en e índice qué filas contienen esa información.
#
# https://www.sqlitetutorial.net/sqlite-index/

# %%
query = """
EXPLAIN QUERY PLAN 
SELECT *
FROM Products
WHERE ProductName = 'Filo Mix'"""
c.execute(query).fetchall()
# Out:
# [(2, 0, 0, 'SCAN Products')]

# %%
c.execute("""CREATE INDEX productname_ind ON Products(ProductName);""").fetchall()
# Out:
# []

# %%
c.execute(query).fetchall()
# Out:
# [(3, 0, 0, 'SEARCH Products USING INDEX productname_ind (ProductName=?)')]

# %%
c.execute("""DROP INDEX productname_ind;""").fetchall()
# Out:
# []

# %%
query = """
SELECT p.ProductName, COUNT(o.OrderID) AS Pedidos, SUM(od.Quantity*p.Price) AS Vendido
FROM Employees e
INNER JOIN Orders o ON o.EmployeeID = e.EmployeeID
INNER JOIN OrderDetails od on o.OrderID = od.OrderID
INNER JOIN Products p on p.ProductID = od.ProductID
WHERE ProductName = 'Filo Mix'
GROUP BY p.ProductName
ORDER BY Vendido DESC"""
# %timeit pd.read_sql(query, con=connection)
# Out:
# 345 µs ± 2.59 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
c.close()
